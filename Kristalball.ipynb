# %% [markdown]
# <a href="https://colab.research.google.com/github/BEKKAMSHIVA/Inventory-management-system-in-bars/blob/main/Kristalball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project Workflow**  ##
# ## Business Problem Statement ##
# ## Data Import and Loading ##
# ## Feature Engineering ##
# ## Final Dataset Preparation ##
# ## Analysing the data ##
# ## EDA (Exploratory Data Analysis) on Selected Bar to Identify Patterns ##
# ##  Function Development to Extract Individual Bar Data ##
# ## ARIMA Optimizer Development ##
# ## Forecasting and Prediction ##

# %% [markdown]
# ## **Business Problem**  ##
#
# ##A hotel chain had  multiple bars and its  facing inventory management issues, including frequent stockouts of high-demand items and overstocking of slow-moving items. These problems lead to increased costs, wastage, and poor customer experience.##
#
# ##So we need to solve this problem that  they will  provided with historical inventory data to develop a forecasting and inventory recommendation system. The system will predict item-level demand and suggest optimal inventory (par) levels to help managers maintain the right stock, avoid shortages, and minimize excess inventory.##

# %% [markdown]
# ## **Data Import and Loading** ##

# %%
# Loading the data.
import pandas as pd
df = pd.read_excel('/content/Consumption Dataset.xlsx')
df
# Out:
#         Date Time Served        Bar Name Alcohol Type      Brand Name  \
# 0    2023-01-01 19:35:00     Smith's Bar          Rum  Captain Morgan
# 1    2023-01-01 10:07:00     Smith's Bar         Wine     Yellow Tail
# 2    2023-01-01 11:26:00   Johnson's Bar        Vodka      Grey Goose
# 3    2023-01-01 13:53:00   Johnson's Bar         Beer           Coors
# 4    2023-01-01 22:28:00   Johnson's Bar         Wine     Yellow Tail
# ...                  ...             ...          ...             ...
# 6570 2024-01-01 21:03:00  Anderson's Bar         Beer           Coors
# 6571 2024-01-01 21:15:00  Anderson's Bar          Rum          Malibu
# 6572 2024-01-01 18:34:00  Anderson's Bar      Whiskey    Jack Daniels
# 6573 2024-01-01 22:46:00    Thomas's Bar        Vodka         Absolut
# 6574 2024-01-01 21:26:00    Thomas's Bar          Rum         Bacardi
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  Closing Balance (ml)
# 0             2.555040e+03        1824.84           0.00               4379.88
# 1             1.344370e+03           0.00           0.00               1344.37
# 2             1.034280e+03           0.00           0.00               1034.28
# 3             2.194530e+03           0.00           0.00               2194.53
# 4             1.020900e+03           0.00           0.00               1020.90
# ...                    ...            ...            ...                   ...
# 6570          2.467080e+03           0.00         321.06               2146.02
# 6571          8.526513e-14        1743.64         175.05               1568.59
# 6572          4.192660e+03           0.00         197.60               3995.06
# 6573          2.424950e+03           0.00         128.52               2296.43
# 6574          1.778360e+03        1195.45         572.60               2401.21
#
# [6575 rows x 8 columns]

# %%
#Shape of the given data set.
df.shape
# Out:
# (6575, 8)

# %%
# column of the given data set.
df.columns
# Out:
# Index(['Date Time Served', 'Bar Name', 'Alcohol Type', 'Brand Name',
#        'Opening Balance (ml)', 'Purchase (ml)', 'Consumed (ml)',
#        'Closing Balance (ml)'],
#       dtype='object')

# %%
# checking the data type of the all the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6575 entries, 0 to 6574
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date Time Served      6575 non-null   datetime64[ns]
#  1   Bar Name              6575 non-null   object
#  2   Alcohol Type          6575 non-null   object
#  3   Brand Name            6575 non-null   object
#  4   Opening Balance (ml)  6575 non-null   float64
#  5   Purchase (ml)         6575 non-null   float64
#  6   Consumed (ml)         6575 non-null   float64
#  7   Closing Balance (ml)  6575 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 411.1+ KB

# %%
# checking  if entire dataset it has any null values:
print(df.isnull().sum().sum())
# Out:
# 0

# %%
#checking any duplicate values in the data set
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #       Feature Engineering       #
# ## The given data is not enough for the analysing so we are creating the the new column from the given data .##
# ##The columns are ##
# ## 1.Date ##
# ## 2.Hour_Minute##
# ## 3.Day of the week ##
# ## 4.Weekday ##
# ## 5.Weekend ##
# ## 6.Month ##
# ## 7.Week number ##
# ## 8.Season ##

# %%
# Extracting  Date
df['Date'] = df['Date Time Served'].dt.date
# Extracting  Hours and minute
df['Hour_Minute'] = df['Date Time Served'].dt.strftime('%H:%M')

# Day name (Monday, Tuesday, etc.)
df['Day_of_Week'] = df['Date Time Served'].dt.day_name()

# Extracting Weekday/Weekend (0=Monday, 6=Sunday)
df['Weekday'] = df['Date Time Served'].dt.weekday
df['Weekend'] = df['Weekday'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')


# Extracting which  Month
df['Month'] = df['Date Time Served'].dt.month

# Extract Week Number
df['Week'] = df['Date Time Served'].dt.isocalendar().week


# Define Season Function
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Apply Season.
df['Season'] = df['Month'].apply(get_season)

# %%
df
# Out:
#         Date Time Served        Bar Name Alcohol Type      Brand Name  \
# 0    2023-01-01 19:35:00     Smith's Bar          Rum  Captain Morgan
# 1    2023-01-01 10:07:00     Smith's Bar         Wine     Yellow Tail
# 2    2023-01-01 11:26:00   Johnson's Bar        Vodka      Grey Goose
# 3    2023-01-01 13:53:00   Johnson's Bar         Beer           Coors
# 4    2023-01-01 22:28:00   Johnson's Bar         Wine     Yellow Tail
# ...                  ...             ...          ...             ...
# 6570 2024-01-01 21:03:00  Anderson's Bar         Beer           Coors
# 6571 2024-01-01 21:15:00  Anderson's Bar          Rum          Malibu
# 6572 2024-01-01 18:34:00  Anderson's Bar      Whiskey    Jack Daniels
# 6573 2024-01-01 22:46:00    Thomas's Bar        Vodka         Absolut
# 6574 2024-01-01 21:26:00    Thomas's Bar          Rum         Bacardi
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# 0             2.555040e+03        1824.84           0.00
# 1             1.344370e+03           0.00           0.00
# 2             1.034280e+03           0.00           0.00
# 3             2.194530e+03           0.00           0.00
# 4             1.020900e+03           0.00           0.00
# ...                    ...            ...            ...
# 6570          2.467080e+03           0.00         321.06
# 6571          8.526513e-14        1743.64         175.05
# 6572          4.192660e+03           0.00         197.60
# 6573          2.424950e+03           0.00         128.52
# 6574          1.778360e+03        1195.45         572.60
#
#       Closing Balance (ml)        Date Hour_Minute Day_of_Week  Weekday  \
# 0                  4379.88  2023-01-01       19:35      Sunday        6
# 1                  1344.37  2023-01-01       10:07      Sunday        6
# 2                  1034.28  2023-01-01       11:26      Sunday        6
# 3                  2194.53  2023-01-01       13:53      Sunday        6
# 4                  1020.90  2023-01-01       22:28      Sunday        6
# ...                    ...         ...         ...         ...      ...
# 6570               2146.02  2024-01-01       21:03      Monday        0
# 6571               1568.59  2024-01-01       21:15      Monday        0
# 6572               3995.06  2024-01-01       18:34      Monday        0
# 6573               2296.43  2024-01-01       22:46      Monday        0
# 6574               2401.21  2024-01-01       21:26      Monday        0
#
#       Weekend  Month  Week  Season
# 0     Weekend      1    52  Winter
# 1     Weekend      1    52  Winter
# 2     Weekend      1    52  Winter
# 3     Weekend      1    52  Winter
# 4     Weekend      1    52  Winter
# ...       ...    ...   ...     ...
# 6570  Weekday      1     1  Winter
# 6571  Weekday      1     1  Winter
# 6572  Weekday      1     1  Winter
# 6573  Weekday      1     1  Winter
# 6574  Weekday      1     1  Winter
#
# [6575 rows x 16 columns]

# %% [markdown]
# ## **Final Dataset Preparation** ##

# %%
# Sort the dataframe by Date Time Served
#Becaue, the given data time is not in correct order.
df = df.sort_values(by='Date Time Served').reset_index(drop=True)
df
# Out:
#         Date Time Served        Bar Name Alcohol Type      Brand Name  \
# 0    2023-01-01 10:07:00     Smith's Bar         Wine     Yellow Tail
# 1    2023-01-01 10:28:00     Brown's Bar        Vodka      Grey Goose
# 2    2023-01-01 11:26:00   Johnson's Bar        Vodka      Grey Goose
# 3    2023-01-01 11:32:00  Anderson's Bar      Whiskey        Jim Beam
# 4    2023-01-01 13:53:00   Johnson's Bar         Beer           Coors
# ...                  ...             ...          ...             ...
# 6570 2024-01-01 19:36:00    Taylor's Bar          Rum  Captain Morgan
# 6571 2024-01-01 21:03:00  Anderson's Bar         Beer           Coors
# 6572 2024-01-01 21:15:00  Anderson's Bar          Rum          Malibu
# 6573 2024-01-01 21:26:00    Thomas's Bar          Rum         Bacardi
# 6574 2024-01-01 22:46:00    Thomas's Bar        Vodka         Absolut
#
#       Opening Balance (ml)  Purchase (ml)  Consumed (ml)  \
# 0             1.344370e+03           0.00           0.00
# 1             2.560440e+03           0.00           0.00
# 2             1.034280e+03           0.00           0.00
# 3             8.720800e+02           0.00           0.00
# 4             2.194530e+03           0.00           0.00
# ...                    ...            ...            ...
# 6570          5.870840e+03        1955.11         440.76
# 6571          2.467080e+03           0.00         321.06
# 6572          8.526513e-14        1743.64         175.05
# 6573          1.778360e+03        1195.45         572.60
# 6574          2.424950e+03           0.00         128.52
#
#       Closing Balance (ml)        Date Hour_Minute Day_of_Week  Weekday  \
# 0                  1344.37  2023-01-01       10:07      Sunday        6
# 1                  2560.44  2023-01-01       10:28      Sunday        6
# 2                  1034.28  2023-01-01       11:26      Sunday        6
# 3                   872.08  2023-01-01       11:32      Sunday        6
# 4                  2194.53  2023-01-01       13:53      Sunday        6
# ...                    ...         ...         ...         ...      ...
# 6570               7385.19  2024-01-01       19:36      Monday        0
# 6571               2146.02  2024-01-01       21:03      Monday        0
# 6572               1568.59  2024-01-01       21:15      Monday        0
# 6573               2401.21  2024-01-01       21:26      Monday        0
# 6574               2296.43  2024-01-01       22:46      Monday        0
#
#       Weekend  Month  Week  Season
# 0     Weekend      1    52  Winter
# 1     Weekend      1    52  Winter
# 2     Weekend      1    52  Winter
# 3     Weekend      1    52  Winter
# 4     Weekend      1    52  Winter
# ...       ...    ...   ...     ...
# 6570  Weekday      1     1  Winter
# 6571  Weekday      1     1  Winter
# 6572  Weekday      1     1  Winter
# 6573  Weekday      1     1  Winter
# 6574  Weekday      1     1  Winter
#
# [6575 rows x 16 columns]

# %% [markdown]
# ## Analysing the data ##

# %%
#This is about descriptive statis about integer and float columns in the given data frame
df.describe()
# Out:
#                     Date Time Served  Opening Balance (ml)  Purchase (ml)  \
# count                           6575           6575.000000    6575.000000
# mean   2023-07-01 09:09:52.033460224           2468.393518     315.841757
# min              2023-01-01 10:07:00              0.000000       0.000000
# 25%              2023-03-30 19:35:00            619.135000       0.000000
# 50%              2023-06-30 18:08:00           1848.440000       0.000000
# 75%              2023-10-01 13:59:30           3853.020000     526.345000
# max              2024-01-01 22:46:00          11862.520000    1999.840000
# std                              NaN           2284.556232     582.120264
#
#        Consumed (ml)  Closing Balance (ml)      Weekday        Month  \
# count    6575.000000           6575.000000  6575.000000  6575.000000
# mean      299.419264           2484.816011     3.006844     6.455665
# min         0.000000              0.000000     0.000000     1.000000
# 25%       156.640000            611.000000     1.000000     3.000000
# 50%       300.390000           1849.840000     3.000000     6.000000
# 75%       450.870000           3906.050000     5.000000     9.000000
# max      1180.580000          11862.520000     6.000000    12.000000
# std       191.903874           2302.362117     2.002914     3.471840
#
#             Week
# count     6575.0
# mean   26.241065
# min          1.0
# 25%         13.0
# 50%         26.0
# 75%         39.0
# max         52.0
# std    15.153885

# %%
# seeing for which time the bars was starting.
overall_start_time = df['Hour_Minute'].min()
overall_end_time = df['Hour_Minute'].max()

print("Overall starting sales time:", overall_start_time)
print("Overall ending sales time:", overall_end_time)

#Morning 10 A.M to Night 10:59(11)P.M
# Out:
# Overall starting sales time: 10:00
# Overall ending sales time: 22:59

# %%
# No.of bars , Alcohol types , brand name in the given data set
columns = ['Bar Name', 'Alcohol Type', 'Brand Name',]

# Loop through columns
for col in columns:
    nunique_val = df[col].nunique()
    unique_vals = df[col].unique()
    value_counts = df[col].value_counts().sort_index()

    print(f"Column: {col}")
    print("Number of unique values:", nunique_val)
    print("Value counts:\n", value_counts)
    print("Unique values:", unique_vals)
    print("-" * 60)
# Out:
# Column: Bar Name
# Number of unique values: 6
# Value counts:
#  Bar Name
# Anderson's Bar    1102
# Brown's Bar       1100
# Johnson's Bar     1106
# Smith's Bar       1078
# Taylor's Bar      1088
# Thomas's Bar      1101
# Name: count, dtype: int64
# Unique values: ["Smith's Bar" "Brown's Bar" "Johnson's Bar" "Anderson's Bar"
#  "Taylor's Bar" "Thomas's Bar"]
# ------------------------------------------------------------
# Column: Alcohol Type
# Number of unique values: 5
# Value counts:
#  Alcohol Type
# Beer       1302
# Rum        1310
# Vodka      1331
# Whiskey    1316
# Wine       1316
# Name: count, dtype: int64
# Unique values: ['Wine' 'Vodka' 'Whiskey' 'Beer' 'Rum']
# ------------------------------------------------------------
# Column: Brand Name
# Number of unique values: 16
# Value counts:
#  Brand Name
# Absolut           432
# Bacardi           414
# Barefoot          424
# Budweiser         300
# Captain Morgan    471
# Coors             325
# Grey Goose        465
# Heineken          314
# Jack Daniels      433
# Jameson           428
# Jim Beam          455
# Malibu            425
# Miller            363
# Smirnoff          434
# Sutter Home       413
# Yellow Tail       479
# Name: count, dtype: int64
# Unique values: ['Yellow Tail' 'Grey Goose' 'Jim Beam' 'Coors' 'Sutter Home' 'Bacardi'
#  'Absolut' 'Jack Daniels' 'Miller' 'Captain Morgan' 'Malibu' 'Jameson'
#  'Smirnoff' 'Heineken' 'Barefoot' 'Budweiser']
# ------------------------------------------------------------

# %% [markdown]
# # So we have 6 different  of bars. #
# # 5 alcohol types. #
# # 16 different brands name. #

# %% [markdown]
# # **EDA (Exploratory Data Analysis)** #
#
# ## Now we will do the EDA part on the one bar to find the  patterns in it .It may use for the building the ForecastOptimizer. ##

# %% [markdown]
# #ANDERS BAR ANALYSIS

# %%
#Total consumed and purchaes of the andersbar.
total_consumed =df['Consumed (ml)'].sum()
total_purchased =df['Purchase (ml)'].sum()
print(total_consumed)
print(total_purchased)

# so , we are purchsing the more rather than consuming.
# so, we need to purches less for the next time.
# Out:
# 1968681.66
# 2076659.5499999998

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create data for plotting
totals = {'Consumed': total_consumed, 'Purchased': total_purchased}

# Set style
sns.set(style="whitegrid")

# Plot
plt.figure(figsize=(3,3))
sns.barplot(x=list(totals.keys()), y=list(totals.values()), palette="viridis")

plt.title("Total Consumed vs Purchased for Anderson's Bar", fontsize=14)
plt.ylabel("Total Volume (ml)", fontsize=12)
plt.xlabel("Category", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-14-1891912614>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(totals.keys()), y=list(totals.values()), palette="viridis")

# %%
#Alcohol type consumption (total sum)
alcohol_type_consumption = df.groupby('Alcohol Type')['Consumed (ml)'].sum().sort_values(ascending=False)
print(alcohol_type_consumption)

# mostly we dont have much differences but vodka consumpiton in on the top.
# Out:
# Alcohol Type
# Vodka      411759.71
# Beer       399498.39
# Rum        393266.84
# Whiskey    384754.46
# Wine       379402.26
# Name: Consumed (ml), dtype: float64

# %%
# Set style
sns.set(style="whitegrid")

# Plot
plt.figure(figsize=(4, 3))
sns.barplot(x=alcohol_type_consumption.values,
            y=alcohol_type_consumption.index,
            palette="magma")

plt.title("Total Consumption by Alcohol Type", fontsize=14)
plt.xlabel("Total Consumed (ml)", fontsize=12)
plt.ylabel("Alcohol Type", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-16-2766538407>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=alcohol_type_consumption.values,

# %%
  #Brand consumption + Fast & Slow movers
brand_consumption = df.groupby('Brand Name')['Consumed (ml)'].sum().sort_values(ascending=False)
brand_average = brand_consumption.mean()
fast_movers = brand_consumption[brand_consumption > brand_average]
slow_movers = brand_consumption[brand_consumption <= brand_average]
print('brand',brand_consumption)
print('fastmovingbrands',fast_movers)
print('slowmovingbrands',slow_movers)
# Out:
# brand Brand Name
# Grey Goose        158924.02
# Jim Beam          139702.43
# Captain Morgan    138035.53
# Barefoot          132312.95
# Yellow Tail       129843.65
# Smirnoff          129176.67
# Bacardi           127951.80
# Malibu            127279.51
# Jack Daniels      125050.89
# Absolut           123659.02
# Jameson           120001.14
# Sutter Home       117245.66
# Miller            107719.33
# Coors              97999.32
# Heineken           96967.09
# Budweiser          96812.65
# Name: Consumed (ml), dtype: float64
# fastmovingbrands Brand Name
# Grey Goose        158924.02
# Jim Beam          139702.43
# Captain Morgan    138035.53
# Barefoot          132312.95
# Yellow Tail       129843.65
# Smirnoff          129176.67
# Bacardi           127951.80
# Malibu            127279.51
# Jack Daniels      125050.89
# Absolut           123659.02
# Name: Consumed (ml), dtype: float64
# slowmovingbrands Brand Name
# Jameson        120001.14
# Sutter Home    117245.66
# Miller         107719.33
# Coors           97999.32
# Heineken        96967.09
# Budweiser       96812.65
# Name: Consumed (ml), dtype: float64

# %%
# Sort descending (for reverse order in plot)
fastmoving = fast_movers.sort_values(ascending=False)
slowmoving = slow_movers.sort_values(ascending=False)

# Set style
sns.set(style="whitegrid")

# Create subplots (2 columns)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot Fast Movers
sns.barplot(x=fastmoving.values, y=fastmoving.index, palette="viridis", ax=axes[0])
axes[0].set_title("Fast Moving Brands", fontsize=14)
axes[0].set_xlabel("Consumed (ml)", fontsize=12)
axes[0].set_ylabel("Brand Name", fontsize=12)
axes[0].tick_params(axis='y', labelsize=10)

# Plot Slow Movers
sns.barplot(x=slowmoving.values, y=slowmoving.index, palette="magma", ax=axes[1])
axes[1].set_title("Slow Moving Brands", fontsize=14)
axes[1].set_xlabel("Consumed (ml)", fontsize=12)
axes[1].set_ylabel("")
axes[1].tick_params(axis='y', labelsize=10)

plt.tight_layout()
plt.show()

# Majority we have the fast moving items only . we have few slow moving items so we nedd to maintain that stock very low..
# Out:
# <ipython-input-18-1154804791>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=fastmoving.values, y=fastmoving.index, palette="viridis", ax=axes[0])
# <ipython-input-18-1154804791>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=slowmoving.values, y=slowmoving.index, palette="magma", ax=axes[1])

# %%
#Time-based aggregations
monthly_consumption = df.groupby('Month')['Consumed (ml)'].sum().reset_index()
monthly_brand_consumption =df.groupby(['Month', 'Brand Name'])['Consumed (ml)'].sum().reset_index()
dayofweek_consumption = df.groupby('Day_of_Week')['Consumed (ml)'].sum().reset_index()
weekly_consumption_yearly =df.groupby('Week')['Consumed (ml)'].sum().reset_index()
weekend_consumption = df.groupby('Weekend')['Consumed (ml)'].sum().reset_index()
monthly_weekend = df.groupby(['Month', 'Weekend'])['Consumed (ml)'].sum().reset_index()
monthly_balance = df.groupby('Month')[['Purchase (ml)', 'Consumed (ml)']].sum().reset_index()
daily_summary =df.groupby('Date')[['Purchase (ml)', 'Consumed (ml)']].sum().reset_index()


print(monthly_consumption)
print(monthly_brand_consumption)
print(dayofweek_consumption)
print(weekly_consumption_yearly)
print(weekend_consumption)
print(monthly_weekend)
print(monthly_balance)
print(daily_summary)
# Out:
#     Month  Consumed (ml)
# 0       1      190070.71
# 1       2      159822.30
# 2       3      158339.96
# 3       4      155860.16
# 4       5      170649.44
# 5       6      159086.67
# 6       7      167976.64
# 7       8      157453.30
# 8       9      155618.19
# 9      10      164376.69
# 10     11      165006.98
# 11     12      164420.62
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut       12724.05
# 1        1         Bacardi       12087.70
# 2        1        Barefoot       13845.02
# 3        1       Budweiser        8802.51
# 4        1  Captain Morgan       14571.05
# ..     ...             ...            ...
# 187     12          Malibu       12031.76
# 188     12          Miller        4406.95
# 189     12        Smirnoff       12833.13
# 190     12     Sutter Home        7689.98
# 191     12     Yellow Tail       14111.62
#
# [192 rows x 3 columns]
#   Day_of_Week  Consumed (ml)
# 0      Friday      283676.29
# 1      Monday      270807.44
# 2    Saturday      281922.49
# 3      Sunday      282815.93
# 4    Thursday      277772.88
# 5     Tuesday      279639.15
# 6   Wednesday      292047.48
#     Week  Consumed (ml)
# 0      1       55062.86
# 1      2       47153.34
# 2      3       40467.10
# 3      4       37635.74
# 4      5       38327.87
# 5      6       41774.35
# 6      7       34072.07
# 7      8       43436.94
# 8      9       37509.45
# 9     10       30109.17
# 10    11       38180.25
# 11    12       41119.79
# 12    13       33819.31
# 13    14       37921.36
# 14    15       30709.75
# 15    16       43050.16
# 16    17       33743.62
# 17    18       37407.65
# 18    19       37169.94
# 19    20       41878.10
# 20    21       40555.75
# 21    22       34059.69
# 22    23       39096.94
# 23    24       40155.72
# 24    25       32573.13
# 25    26       38683.81
# 26    27       33327.21
# 27    28       39273.35
# 28    29       38914.64
# 29    30       37834.19
# 30    31       40341.71
# 31    32       38236.01
# 32    33       29555.98
# 33    34       36740.00
# 34    35       34532.13
# 35    36       33584.61
# 36    37       39722.37
# 37    38       34870.39
# 38    39       37362.22
# 39    40       37751.77
# 40    41       37782.08
# 41    42       39092.89
# 42    43       35402.77
# 43    44       38238.15
# 44    45       40241.75
# 45    46       39631.87
# 46    47       32937.77
# 47    48       36709.77
# 48    49       37571.91
# 49    50       47155.52
# 50    51       34069.92
# 51    52       32126.82
#    Weekend  Consumed (ml)
# 0  Weekday     1403943.24
# 1  Weekend      564738.42
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday      139845.39
# 1       1  Weekend       50225.32
# 2       2  Weekday      120345.28
# 3       2  Weekend       39477.02
# 4       3  Weekday      116972.59
# 5       3  Weekend       41367.37
# 6       4  Weekday      102847.46
# 7       4  Weekend       53012.70
# 8       5  Weekday      126943.77
# 9       5  Weekend       43705.67
# 10      6  Weekday      115201.10
# 11      6  Weekend       43885.57
# 12      7  Weekday      112885.42
# 13      7  Weekend       55091.22
# 14      8  Weekday      114775.21
# 15      8  Weekend       42678.09
# 16      9  Weekday      105630.76
# 17      9  Weekend       49987.43
# 18     10  Weekday      115139.47
# 19     10  Weekend       49237.22
# 20     11  Weekday      119595.56
# 21     11  Weekend       45411.42
# 22     12  Weekday      113761.23
# 23     12  Weekend       50659.39
#     Month  Purchase (ml)  Consumed (ml)
# 0       1      214487.95      190070.71
# 1       2      167349.52      159822.30
# 2       3      197812.85      158339.96
# 3       4      162543.87      155860.16
# 4       5      162170.12      170649.44
# 5       6      181356.77      159086.67
# 6       7      180098.20      167976.64
# 7       8      157802.34      157453.30
# 8       9      163787.43      155618.19
# 9      10      164185.82      164376.69
# 10     11      172887.76      165006.98
# 11     12      152176.92      164420.62
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01        3225.60           0.00
# 1    2023-01-02        6353.76        6601.69
# 2    2023-01-03        7399.94        7124.15
# 3    2023-01-04       11111.30        6065.93
# 4    2023-01-05        8981.76        8048.48
# ..          ...            ...            ...
# 361  2023-12-28        1865.94        5267.46
# 362  2023-12-29        4771.26        6064.13
# 363  2023-12-30        2244.99        4568.21
# 364  2023-12-31        2462.15        5161.62
# 365  2024-01-01       11937.92        5223.71
#
# [366 rows x 3 columns]

# %%
# Monthly Consumption
sns.lineplot(data=monthly_consumption, x='Month', y='Consumed (ml)', marker='o', color='teal')

plt.title("Monthly Total Consumption", fontsize=16)
plt.xlabel("Month", fontsize=14)
plt.ylabel("Total Consumed (ml)", fontsize=14)
plt.xticks(range(1, 13))
plt.grid(True)
plt.tight_layout()
plt.show()
# we have the highest consumption inthe first monthe and its gradualy decrasing.

# %%
plt.figure(figsize=(16, 8))
sns.barplot(data=monthly_brand_consumption, x='Month', y='Consumed (ml)', hue='Brand Name')

plt.title('Monthly Consumption per Brand', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Consumed (ml)', fontsize=14)
plt.legend(title='Brand Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
#Monthly brand consumption in anderson bar.

# %%
# Consumption day of the week.
# Sorting days to show proper week order
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
dayofweek_consumption['Day_of_Week'] = pd.Categorical(dayofweek_consumption['Day_of_Week'], categories=order, ordered=True)
dayofweek_consumption = dayofweek_consumption.sort_values('Day_of_Week')

# Plotting
plt.figure(figsize=(6, 4))
sns.barplot(data=dayofweek_consumption, x='Day_of_Week', y='Consumed (ml)', palette='crest')

plt.title("Total Consumption by Day of Week", fontsize=16)
plt.xlabel("Day of Week", fontsize=14)
plt.ylabel("Total Consumed (ml)", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# we can see the almost they consumption is same but on monday we have less in it.
# Out:
# <ipython-input-22-4144290941>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=dayofweek_consumption, x='Day_of_Week', y='Consumed (ml)', palette='crest')

# %%
plt.figure(figsize=(12, 6))
plt.plot(weekly_consumption_yearly['Week'], weekly_consumption_yearly['Consumed (ml)'], marker='o')
plt.title("Weekly Consumption Pattern - Anderson's Bar")
plt.xlabel("Week Number")
plt.ylabel("Consumed (ml)")
plt.grid()
plt.show()
#This trend show the weekly wise report through out the year .

# %%
plt.figure(figsize=(3,3))
sns.barplot(data=weekend_consumption, x='Weekend', y='Consumed (ml)', palette='coolwarm')

plt.title("Weekend vs Weekday Consumption - Anderson's Bar")
plt.xlabel("Day Type")
plt.ylabel("Total Consumed (ml)")
plt.grid(axis='y')
plt.show()
# we can see the consumption in more in weekday compared to the weekend
# Out:
# <ipython-input-25-544621521>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=weekend_consumption, x='Weekend', y='Consumed (ml)', palette='coolwarm')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=monthly_weekend, x='Month', y='Consumed (ml)', hue='Weekend')
plt.title("Monthly Weekend vs Weekday Consumption")
plt.xticks(rotation=45)
plt.show()
# seeing the in the monthe of the year  difference between weekends and weekdays.

# %%
import numpy as np

months = monthly_balance['Month']
purchase = monthly_balance['Purchase (ml)']
consumed = monthly_balance['Consumed (ml)']

# Bar width and positions
bar_width = 0.35
x = np.arange(len(months))

plt.figure(figsize=(12, 6))
plt.bar(x - bar_width/2, purchase, bar_width, label='Purchase (ml)', color='skyblue')
plt.bar(x + bar_width/2, consumed, bar_width, label='Consumed (ml)', color='salmon')

plt.title('Monthly Purchase vs Consumption', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Quantity (ml)', fontsize=14)
plt.xticks(x, months)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# we can see the mothly wise how much we purchaed and comsumped in it..

# %%
plt.figure(figsize=(15, 6))

# Plot Purchase
plt.plot(daily_summary['Date'], daily_summary['Purchase (ml)'], label='Purchase (ml)', color='skyblue', linewidth=2)

# Plot Consumption
plt.plot(daily_summary['Date'], daily_summary['Consumed (ml)'], label='Consumed (ml)', color='salmon', linewidth=2)

plt.title('Daily Purchase vs Consumption', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Quantity (ml)', fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# This is the summery of the purchase and consumption
#so came to consulsion that we are consumption is more rather than purchases.

# %%
# Fixing the  Thresholds for total consumption
#Taking the average as month  because taking the single day we are getting very low value because it have lot of 0 in it
monthly_series = df.groupby('Month')['Consumed (ml)'].sum()
avg_monthly_consumption = monthly_series.mean()
stockout_threshold = avg_monthly_consumption * 0.5
overstock_threshold = avg_monthly_consumption * 1.2
print("Average Monthly Consumption:", avg_monthly_consumption)
print("Stockout Threshold:", stockout_threshold)
print("Overstock Threshold:", overstock_threshold)

# we are fixing stockout threshold value as 50% more for the average values
# we are fixing the overstock threshold values as 150% more for the overstock values.
# Out:
# Average Monthly Consumption: 164056.80499999996
# Stockout Threshold: 82028.40249999998
# Overstock Threshold: 196868.16599999994

# %%
plt.figure(figsize=(12, 6))

# Bar plot for monthly consumption
monthly_series.plot(kind='bar', color='skyblue')

# Plot thresholds
plt.axhline(y=avg_monthly_consumption, color='green', linestyle='--', linewidth=2, label='Average Consumption')
plt.axhline(y=stockout_threshold, color='red', linestyle='--', linewidth=2, label='Stockout Threshold')
plt.axhline(y=overstock_threshold, color='orange', linestyle='--', linewidth=2, label='Overstock Threshold')

plt.title('Monthly Consumption with Stockout & Overstock Thresholds', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Consumed (ml)', fontsize=14)
plt.xticks(rotation=0)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# By these values only we  will adjust our stock in the bars.
# see that no stock is not out.
# they are not sold in the bars which leads to the loss to the bars.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

analysis_result = {} # Initialize analysis_result as an empty dictionary

monthly_series = monthly_series.reset_index().set_index('Month')
if len(monthly_series) >= 6:
   result = seasonal_decompose(monthly_series['Consumed (ml)'], model='additive', period=6)
   analysis_result['Seasonality Decomposition'] = result
else:
   analysis_result['Seasonality Decomposition'] = None

print(analysis_result)
# Out:
# {'Seasonality Decomposition': <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4f784ee10>}

# %%
if analysis_result['Seasonality Decomposition'] is not None:
    result = analysis_result['Seasonality Decomposition']

    print("Observed values:")
    print(result.observed)

    print("\nTrend values:")
    print(result.trend)

    print("\nSeasonal values:")
    print(result.seasonal)

    print("\nResidual values:")
    print(result.resid)
else:
    print("Decomposition could not be performed due to insufficient data.")
# Out:
# Observed values:
# Month
# 1     190070.71
# 2     159822.30
# 3     158339.96
# 4     155860.16
# 5     170649.44
# 6     159086.67
# 7     167976.64
# 8     157453.30
# 9     155618.19
# 10    164376.69
# 11    165006.98
# 12    164420.62
# Name: Consumed (ml), dtype: float64
#
# Trend values:
# Month
# 1               NaN
# 2               NaN
# 3               NaN
# 4     163797.034167
# 5     161758.445000
# 6     161334.214167
# 7     161817.110833
# 8     162056.616667
# 9     162030.907500
# 10              NaN
# 11              NaN
# 12              NaN
# Name: trend, dtype: float64
#
# Seasonal values:
# Month
# 1     7184.517222
# 2    -3578.328611
# 3    -5387.729444
# 4    -6911.886111
# 5     9915.983056
# 6    -1222.556111
# 7     7184.517222
# 8    -3578.328611
# 9    -5387.729444
# 10   -6911.886111
# 11    9915.983056
# 12   -1222.556111
# Name: seasonal, dtype: float64
#
# Residual values:
# Month
# 1             NaN
# 2             NaN
# 3             NaN
# 4    -1024.988056
# 5    -1024.988056
# 6    -1024.988056
# 7    -1024.988056
# 8    -1024.988056
# 9    -1024.988056
# 10            NaN
# 11            NaN
# 12            NaN
# Name: resid, dtype: float64

# %%
# Since you already have the result:
if analysis_result['Seasonality Decomposition'] is not None:
    result = analysis_result['Seasonality Decomposition']

    # Plot all components
    plt.figure(figsize=(12, 8))
    result.plot()
    plt.suptitle('Seasonal Decomposition', fontsize=16)
    plt.tight_layout()
    plt.show()
else:
    print("Not enough data to perform decomposition.")

  # Seasonal analysis means
  #  Trend:The long-term increase or decrease in consumption (e.g., over the year, people might drink more or less overall)
  #  Seasonality: The repeating patterns that happen regularly — like higher alcohol sales in December (Christmas/New Year), or summer vs winter demand.
  #  Residual (Noise): Random ups and downs that don't follow any clear trend or seasonality — like one-off events, promotions, or weather changes.
  #  Observed:  This is simply the raw data you have.

# %%
seasonal_consumption = df.groupby(['Season', 'Alcohol Type', 'Brand Name'])['Consumed (ml)'].sum().reset_index()
season_pivot = seasonal_consumption.pivot_table(
        values='Consumed (ml)',
        index=['Alcohol Type', 'Brand Name'],
        columns='Season',
        fill_value=0
    )
analysis_result['Standby Season-Wise'] = season_pivot

print(season_pivot)

# NOW we can see the season wise consumption
#Note: Vizualtion in not required for this.
# Out:
# Season                           Fall    Spring    Summer    Winter
# Alcohol Type Brand Name
# Beer         Budweiser       22054.89  24059.29  27800.75  22897.72
#              Coors           18783.97  23439.58  26879.05  28896.72
#              Heineken        20912.28  24431.28  24237.30  27386.23
#              Miller          29002.59  27197.64  28880.53  22638.57
# Rum          Bacardi         31461.29  24728.08  35782.09  35980.34
#              Captain Morgan  34578.74  40170.97  25905.22  37380.60
#              Malibu          30325.70  26741.79  35068.93  35143.09
# Vodka        Absolut         34062.22  29213.26  29177.06  31206.48
#              Grey Goose      39746.02  42896.72  35818.28  40463.00
#              Smirnoff        31836.58  27976.92  35775.53  33587.64
# Whiskey      Jack Daniels    25918.22  35070.45  29344.76  34717.46
#              Jameson         28791.86  29568.29  29535.31  32105.68
#              Jim Beam        37710.10  34018.02  33289.50  34684.81
# Wine         Barefoot        35416.17  35308.02  28749.52  32839.24
#              Sutter Home     32407.45  25276.69  30359.70  29201.82
#              Yellow Tail     31993.78  34752.56  27913.08  35184.23

# %%
 # 8. Alcohol Type Monthly Averages
alcohol_monthly = df.groupby(['Month', 'Alcohol Type'])['Consumed (ml)'].sum().reset_index()
alcohol_type_avg = alcohol_monthly.groupby('Alcohol Type')['Consumed (ml)'].mean().reset_index()
analysis_result['Alcohol Type Monthly Average'] = alcohol_type_avg
print(alcohol_monthly)
print(alcohol_type_avg)
# Out:
#     Month Alcohol Type  Consumed (ml)
# 0       1         Beer       38562.24
# 1       1          Rum       42944.06
# 2       1        Vodka       39344.21
# 3       1      Whiskey       34270.36
# 4       1         Wine       34949.84
# 5       2         Beer       33760.23
# 6       2          Rum       31185.18
# 7       2        Vodka       30058.42
# 8       2      Whiskey       34208.68
# 9       2         Wine       30609.79
# 10      3         Beer       32378.35
# 11      3          Rum       29257.57
# 12      3        Vodka       31820.49
# 13      3      Whiskey       33691.98
# 14      3         Wine       31191.57
# 15      4         Beer       31533.90
# 16      4          Rum       27718.65
# 17      4        Vodka       33014.48
# 18      4      Whiskey       31167.80
# 19      4         Wine       32425.33
# 20      5         Beer       35215.54
# 21      5          Rum       34664.62
# 22      5        Vodka       35251.93
# 23      5      Whiskey       33796.98
# 24      5         Wine       31720.37
# 25      6         Beer       33444.85
# 26      6          Rum       35326.71
# 27      6        Vodka       30689.48
# 28      6      Whiskey       30260.18
# 29      6         Wine       29365.45
# 30      7         Beer       37486.85
# 31      7          Rum       31124.56
# 32      7        Vodka       37781.64
# 33      7      Whiskey       29833.97
# 34      7         Wine       31749.62
# 35      8         Beer       36865.93
# 36      8          Rum       30304.97
# 37      8        Vodka       32299.75
# 38      8      Whiskey       32075.42
# 39      8         Wine       25907.23
# 40      9         Beer       29220.77
# 41      9          Rum       32952.65
# 42      9        Vodka       28204.02
# 43      9      Whiskey       31259.72
# 44      9         Wine       33981.03
# 45     10         Beer       31303.72
# 46     10          Rum       36871.33
# 47     10        Vodka       39186.18
# 48     10      Whiskey       28276.12
# 49     10         Wine       28739.34
# 50     11         Beer       30229.24
# 51     11          Rum       26541.75
# 52     11        Vodka       38254.62
# 53     11      Whiskey       32884.34
# 54     11         Wine       37097.03
# 55     12         Beer       29496.77
# 56     12          Rum       34374.79
# 57     12        Vodka       35854.49
# 58     12      Whiskey       33028.91
# 59     12         Wine       31665.66
#   Alcohol Type  Consumed (ml)
# 0         Beer   33291.532500
# 1          Rum   32772.236667
# 2        Vodka   34313.309167
# 3      Whiskey   32062.871667
# 4         Wine   31616.855000

# %%
# Alcohol Type Thresholds
alcohol_type_avg['Stockout Threshold'] = alcohol_type_avg['Consumed (ml)'] * 0.5
alcohol_type_avg['Overstock Threshold'] = alcohol_type_avg['Consumed (ml)'] * 1.2
analysis_result['Alcohol Type Thresholds'] = alcohol_type_avg
# In this we are fixing  threeshold values to alcohol types

# %%
# this is the daily analysis of the alcohol  wise and brand wise
daily_brand_alcohol = df.groupby(['Date', 'Alcohol Type', 'Brand Name'])['Consumed (ml)'].sum().reset_index()
analysis_result['Daily Brand Alcohol Consumption'] = daily_brand_alcohol

print(analysis_result)
# Out:
# {'Seasonality Decomposition': <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4f784ee10>, 'Standby Season-Wise': Season                           Fall    Spring    Summer    Winter
# Alcohol Type Brand Name
# Beer         Budweiser       22054.89  24059.29  27800.75  22897.72
#              Coors           18783.97  23439.58  26879.05  28896.72
#              Heineken        20912.28  24431.28  24237.30  27386.23
#              Miller          29002.59  27197.64  28880.53  22638.57
# Rum          Bacardi         31461.29  24728.08  35782.09  35980.34
#              Captain Morgan  34578.74  40170.97  25905.22  37380.60
#              Malibu          30325.70  26741.79  35068.93  35143.09
# Vodka        Absolut         34062.22  29213.26  29177.06  31206.48
#              Grey Goose      39746.02  42896.72  35818.28  40463.00
#              Smirnoff        31836.58  27976.92  35775.53  33587.64
# Whiskey      Jack Daniels    25918.22  35070.45  29344.76  34717.46
#              Jameson         28791.86  29568.29  29535.31  32105.68
#              Jim Beam        37710.10  34018.02  33289.50  34684.81
# Wine         Barefoot        35416.17  35308.02  28749.52  32839.24
#              Sutter Home     32407.45  25276.69  30359.70  29201.82
#              Yellow Tail     31993.78  34752.56  27913.08  35184.23, 'Alcohol Type Monthly Average':   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer   33291.532500        16645.766250            39949.839
# 1          Rum   32772.236667        16386.118333            39326.684
# 2        Vodka   34313.309167        17156.654583            41175.971
# 3      Whiskey   32062.871667        16031.435833            38475.446
# 4         Wine   31616.855000        15808.427500            37940.226, 'Alcohol Type Thresholds':   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer   33291.532500        16645.766250            39949.839
# 1          Rum   32772.236667        16386.118333            39326.684
# 2        Vodka   34313.309167        17156.654583            41175.971
# 3      Whiskey   32062.871667        16031.435833            38475.446
# 4         Wine   31616.855000        15808.427500            37940.226, 'Daily Brand Alcohol Consumption':             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01         Beer           Coors           0.00
# 1     2023-01-01         Beer          Miller           0.00
# 2     2023-01-01          Rum         Bacardi           0.00
# 3     2023-01-01          Rum  Captain Morgan           0.00
# 4     2023-01-01          Rum          Malibu           0.00
# ...          ...          ...             ...            ...
# 4161  2024-01-01        Vodka      Grey Goose         720.02
# 4162  2024-01-01        Vodka        Smirnoff         252.39
# 4163  2024-01-01      Whiskey    Jack Daniels         197.60
# 4164  2024-01-01      Whiskey        Jim Beam         253.33
# 4165  2024-01-01         Wine        Barefoot         155.61
#
# [4166 rows x 4 columns]}

# %% [markdown]
# ##Now we have done some anlysis the the Andersons bar and this values are use for the building the optimizer ##
#
# ##Now it may lead to difficult that to got the each bar and extrating vales ##
#
# ## To slove this issues we have created a function in that all the anlaysis has stored in it and results are stored belong the bars names only ##

# %% [markdown]
# ## Function Development to Extract Individual Bar Data ##

# %%
#               created function to collect the analysis in the all bars .
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# Updated analyze_bar_main including 'Daily Brand Alcohol Consumption'
def analyze_bar_main(df, bar_name):
    # Filter data for selected bar
    bar_df = df[df['Bar Name'] == bar_name].copy()

    analysis_result = {}

    # 1. Total consumption and purchase
    total_consumed = bar_df['Consumed (ml)'].sum()
    total_purchased = bar_df['Purchase (ml)'].sum()
    analysis_result['Total Consumed (ml)'] = total_consumed
    analysis_result['Total Purchased (ml)'] = total_purchased

    # 2. Alcohol type consumption (total sum)
    alcohol_type_consumption = bar_df.groupby('Alcohol Type')['Consumed (ml)']\
        .sum().sort_values(ascending=False)
    analysis_result['Alcohol Type Consumption'] = alcohol_type_consumption

    # 3. Brand consumption + Fast & Slow movers
    brand_consumption = bar_df.groupby('Brand Name')['Consumed (ml)']\
        .sum().sort_values(ascending=False)
    brand_average = brand_consumption.mean()
    fast_movers = brand_consumption[brand_consumption > brand_average]
    slow_movers = brand_consumption[brand_consumption <= brand_average]
    analysis_result['Brand Consumption'] = brand_consumption
    analysis_result['Fast Movers'] = fast_movers
    analysis_result['Slow Movers'] = slow_movers

    # 4. Time-based aggregations
    monthly_consumption = bar_df.groupby('Month')['Consumed (ml)'].sum().reset_index()
    monthly_brand_consumption = bar_df.groupby(['Month', 'Brand Name'])['Consumed (ml)']\
        .sum().reset_index()
    dayofweek_consumption = bar_df.groupby('Day_of_Week')['Consumed (ml)']\
        .sum().reset_index()
    weekly_consumption_yearly = bar_df.groupby('Week')['Consumed (ml)']\
        .sum().reset_index()
    weekend_consumption = bar_df.groupby('Weekend')['Consumed (ml)']\
        .sum().reset_index()
    monthly_weekend = bar_df.groupby(['Month', 'Weekend'])['Consumed (ml)']\
        .sum().reset_index()
    monthly_balance = bar_df.groupby('Month')[['Purchase (ml)', 'Consumed (ml)']]\
        .sum().reset_index()
    daily_summary = bar_df.groupby('Date')[['Purchase (ml)', 'Consumed (ml)']]\
        .sum().reset_index()
    analysis_result['Monthly Consumption'] = monthly_consumption
    analysis_result['Monthly Brand Consumption'] = monthly_brand_consumption
    analysis_result['Day Of Week Consumption'] = dayofweek_consumption
    analysis_result['Weekly Consumption Yearly'] = weekly_consumption_yearly
    analysis_result['Weekend Consumption'] = weekend_consumption
    analysis_result['Monthly Weekend'] = monthly_weekend
    analysis_result['Monthly Balance'] = monthly_balance
    analysis_result['Daily Summary'] = daily_summary

    # 5. Thresholds for total consumption
    monthly_series = bar_df.groupby('Month')['Consumed (ml)'].sum()
    avg_monthly_consumption = monthly_series.mean()
    stockout_threshold = avg_monthly_consumption * 0.5
    overstock_threshold = avg_monthly_consumption * 1.2
    analysis_result['Avg Monthly Consumption'] = avg_monthly_consumption
    analysis_result['Stockout Threshold'] = stockout_threshold
    analysis_result['Overstock Threshold'] = overstock_threshold

    # 6. Seasonality Decomposition
    monthly_series = monthly_series.reset_index().set_index('Month')
    if len(monthly_series) >= 6:
        result = seasonal_decompose(monthly_series['Consumed (ml)'], model='additive', period=6)
        analysis_result['Seasonality Decomposition'] = result
    else:
        analysis_result['Seasonality Decomposition'] = None

    # 7. Season-Wise Analysis
    seasonal_consumption = bar_df.groupby(['Season', 'Alcohol Type', 'Brand Name'])['Consumed (ml)']\
        .sum().reset_index()
    season_pivot = seasonal_consumption.pivot_table(
        values='Consumed (ml)',
        index=['Alcohol Type', 'Brand Name'],
        columns='Season',
        fill_value=0
    )
    analysis_result['Standby Season-Wise'] = season_pivot

    # 8. Alcohol Type Monthly Averages
    alcohol_monthly = bar_df.groupby(['Month', 'Alcohol Type'])['Consumed (ml)']\
        .sum().reset_index()
    alcohol_type_avg = alcohol_monthly.groupby('Alcohol Type')['Consumed (ml)']\
        .mean().reset_index()
    analysis_result['Alcohol Type Monthly Average'] = alcohol_type_avg

    # 9. Alcohol Type Thresholds
    alcohol_type_avg['Stockout Threshold'] = alcohol_type_avg['Consumed (ml)'] * 0.5
    alcohol_type_avg['Overstock Threshold'] = alcohol_type_avg['Consumed (ml)'] * 1.2
    analysis_result['Alcohol Type Thresholds'] = alcohol_type_avg

    # — NEW: Daily brand-alcohol consumption as DataFrame
    daily_brand_alcohol = bar_df.groupby(['Date', 'Alcohol Type', 'Brand Name'])['Consumed (ml)']\
        .sum().reset_index()
    analysis_result['Daily Brand Alcohol Consumption'] = daily_brand_alcohol

    return analysis_result

# %% [markdown]
# ## Now we will pass the different bars to this function to analyse the patterns of that bar to pass to the optimizer ##

# %%
# Analyze Anderson's bar
# Run the analysis
andersonsbar_analysis= analyze_bar_main(df, "Anderson's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in andersonsbar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in andersonsbar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 335818.94999999995
#
# Key: Total Purchased (ml)
# Value:
# 354200.71
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Whiskey    70459.96
# Wine       69565.40
# Beer       67135.59
# Rum        66628.06
# Vodka      62029.94
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Captain Morgan    27066.83
# Barefoot          26989.63
# Bacardi           25966.47
# Jim Beam          25888.54
# Smirnoff          24889.67
# Grey Goose        24026.36
# Jameson           23117.10
# Sutter Home       22815.74
# Coors             21479.29
# Jack Daniels      21454.32
# Yellow Tail       19760.03
# Miller            18180.30
# Heineken          17413.71
# Malibu            13594.76
# Absolut           13113.91
# Budweiser         10062.29
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Captain Morgan    27066.83
# Barefoot          26989.63
# Bacardi           25966.47
# Jim Beam          25888.54
# Smirnoff          24889.67
# Grey Goose        24026.36
# Jameson           23117.10
# Sutter Home       22815.74
# Coors             21479.29
# Jack Daniels      21454.32
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Yellow Tail    19760.03
# Miller         18180.30
# Heineken       17413.71
# Malibu         13594.76
# Absolut        13113.91
# Budweiser      10062.29
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       29835.98
# 1       2       27977.04
# 2       3       27823.24
# 3       4       28625.20
# 4       5       30066.96
# 5       6       30561.67
# 6       7       30698.74
# 7       8       26200.02
# 8       9       24194.43
# 9      10       27268.56
# 10     11       24750.93
# 11     12       27816.18
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut        1309.92
# 1        1         Bacardi        1195.20
# 2        1        Barefoot        2531.60
# 3        1       Budweiser         939.07
# 4        1  Captain Morgan        2332.80
# ..     ...             ...            ...
# 184     12        Jim Beam        3820.21
# 185     12          Miller         418.15
# 186     12        Smirnoff        2233.77
# 187     12     Sutter Home        1019.84
# 188     12     Yellow Tail        2603.27
#
# [189 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       50151.98
# 1      Monday       42470.86
# 2    Saturday       52867.91
# 3      Sunday       50491.08
# 4    Thursday       43916.52
# 5     Tuesday       44269.07
# 6   Wednesday       51651.53
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1        7173.98
# 1      2        9534.18
# 2      3        7000.71
# 3      4        5526.58
# 4      5        6528.59
# 5      6        5940.41
# 6      7        5440.70
# 7      8        8715.18
# 8      9        5762.36
# 9     10        6475.13
# 10    11        7996.35
# 11    12        6007.64
# 12    13        5386.72
# 13    14        6885.10
# 14    15        6503.00
# 15    16        7230.85
# 16    17        6153.98
# 17    18        8797.90
# 18    19        6271.16
# 19    20        5121.38
# 20    21        7433.95
# 21    22        6722.19
# 22    23        8005.09
# 23    24        5285.85
# 24    25        6739.88
# 25    26        8300.57
# 26    27        7232.88
# 27    28        7652.33
# 28    29        5390.55
# 29    30        6994.95
# 30    31        7921.74
# 31    32        5708.04
# 32    33        4724.77
# 33    34        6432.51
# 34    35        5452.86
# 35    36        4965.28
# 36    37        6709.11
# 37    38        5321.54
# 38    39        5573.59
# 39    40        7760.17
# 40    41        4825.36
# 41    42        5764.53
# 42    43        5045.24
# 43    44        7843.07
# 44    45        5312.55
# 45    46        5129.14
# 46    47        5363.35
# 47    48        6374.49
# 48    49        6978.59
# 49    50        7129.10
# 50    51        5760.65
# 51    52        5513.13
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      232459.96
# 1  Weekend      103358.99
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       21113.42
# 1       1  Weekend        8722.56
# 2       2  Weekday       21337.52
# 3       2  Weekend        6639.52
# 4       3  Weekday       19571.32
# 5       3  Weekend        8251.92
# 6       4  Weekday       19583.02
# 7       4  Weekend        9042.18
# 8       5  Weekday       22770.65
# 9       5  Weekend        7296.31
# 10      6  Weekday       23001.15
# 11      6  Weekend        7560.52
# 12      7  Weekday       19437.50
# 13      7  Weekend       11261.24
# 14      8  Weekday       17095.34
# 15      8  Weekend        9104.68
# 16      9  Weekday       16600.47
# 17      9  Weekend        7593.96
# 18     10  Weekday       18945.41
# 19     10  Weekend        8323.15
# 20     11  Weekday       15444.54
# 21     11  Weekend        9306.39
# 22     12  Weekday       17559.62
# 23     12  Weekend       10256.56
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       36722.65       29835.98
# 1       2       31881.83       27977.04
# 2       3       32738.93       27823.24
# 3       4       31789.46       28625.20
# 4       5       31789.99       30066.96
# 5       6       31130.57       30561.67
# 6       7       25881.75       30698.74
# 7       8       24311.39       26200.02
# 8       9       29819.84       24194.43
# 9      10       18334.95       27268.56
# 10     11       29927.55       24750.93
# 11     12       29871.80       27816.18
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01           0.00           0.00
# 1    2023-01-02           0.00         559.17
# 2    2023-01-03        1911.30        1107.11
# 3    2023-01-04        2791.30         656.24
# 4    2023-01-05           0.00        1272.46
# ..          ...            ...            ...
# 361  2023-12-28         658.22        1058.93
# 362  2023-12-29           0.00         502.15
# 363  2023-12-30           0.00         617.73
# 364  2023-12-31           0.00        1113.60
# 365  2024-01-01        1743.64         693.71
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 27984.912500000002
#
# Key: Stockout Threshold
# Value:
# 13992.456250000001
#
# Key: Overstock Threshold
# Value:
# 33581.895000000004
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4fd11f350>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       1193.68  1368.97  5381.58  2118.06
#              Coors           2285.39  5893.46  6205.52  7094.92
#              Heineken        2178.35  4946.26  4467.79  5821.31
#              Miller          5990.53  4230.41  4564.17  3395.19
# Rum          Bacardi         3233.11  7044.32  9149.63  6539.41
#              Captain Morgan  8137.22  7648.33  5436.45  5844.83
#              Malibu          3149.59  1797.18  4951.91  3696.08
# Vodka        Absolut         3264.55  3581.91  3099.43  3168.02
#              Grey Goose      4222.90  8630.72  4975.60  6197.14
#              Smirnoff        5855.60  4985.04  6780.89  7268.14
# Whiskey      Jack Daniels    7222.99  5530.60  3266.90  5433.83
#              Jameson         5322.89  6090.74  6162.16  5541.31
#              Jim Beam        5586.68  6171.77  6625.86  7504.23
# Wine         Barefoot        9943.82  6014.98  4820.27  6210.56
#              Sutter Home     5754.14  6132.96  7396.67  3531.97
#              Yellow Tail     2872.48  6447.75  4175.60  6264.20
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5594.632500         2797.316250             6713.559
# 1          Rum    5552.338333         2776.169167             6662.806
# 2        Vodka    5169.161667         2584.580833             6202.994
# 3      Whiskey    5871.663333         2935.831667             7045.996
# 4         Wine    5797.116667         2898.558333             6956.540
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5594.632500         2797.316250             6713.559
# 1          Rum    5552.338333         2776.169167             6662.806
# 2        Vodka    5169.161667         2584.580833             6202.994
# 3      Whiskey    5871.663333         2935.831667             7045.996
# 4         Wine    5797.116667         2898.558333             6956.540
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type    Brand Name  Consumed (ml)
# 0     2023-01-01         Beer        Miller           0.00
# 1     2023-01-01          Rum       Bacardi           0.00
# 2     2023-01-01      Whiskey      Jim Beam           0.00
# 3     2023-01-01         Wine   Sutter Home           0.00
# 4     2023-01-02         Beer         Coors         440.55
# ...          ...          ...           ...            ...
# 1097  2023-12-31      Whiskey      Jim Beam         100.44
# 1098  2023-12-31         Wine   Yellow Tail         129.41
# 1099  2024-01-01         Beer         Coors         321.06
# 1100  2024-01-01          Rum        Malibu         175.05
# 1101  2024-01-01      Whiskey  Jack Daniels         197.60
#
# [1102 rows x 4 columns]

# %%
# Analyze Brown"s Bar
# Run the analysis
BrownsBar_analysis= analyze_bar_main(df, "Brown's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in BrownsBar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in BrownsBar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 326371.92
#
# Key: Total Purchased (ml)
# Value:
# 333319.08999999997
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Wine       69469.77
# Beer       66743.84
# Whiskey    66459.07
# Vodka      63333.82
# Rum        60365.42
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Yellow Tail       29588.63
# Grey Goose        27873.30
# Jameson           23813.13
# Jim Beam          23777.58
# Bacardi           23420.89
# Sutter Home       20634.92
# Heineken          19537.43
# Barefoot          19246.22
# Malibu            19057.03
# Jack Daniels      18868.36
# Absolut           18358.23
# Captain Morgan    17887.50
# Smirnoff          17102.29
# Budweiser         16696.49
# Miller            16480.91
# Coors             14029.01
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Yellow Tail    29588.63
# Grey Goose     27873.30
# Jameson        23813.13
# Jim Beam       23777.58
# Bacardi        23420.89
# Sutter Home    20634.92
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Heineken          19537.43
# Barefoot          19246.22
# Malibu            19057.03
# Jack Daniels      18868.36
# Absolut           18358.23
# Captain Morgan    17887.50
# Smirnoff          17102.29
# Budweiser         16696.49
# Miller            16480.91
# Coors             14029.01
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       29257.62
# 1       2       22454.08
# 2       3       25427.82
# 3       4       22351.72
# 4       5       33259.53
# 5       6       26145.00
# 6       7       30134.79
# 7       8       28915.42
# 8       9       25062.47
# 9      10       29064.15
# 10     11       28462.73
# 11     12       25836.59
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut        3237.44
# 1        1         Bacardi        2065.65
# 2        1        Barefoot        2231.09
# 3        1       Budweiser        1408.89
# 4        1  Captain Morgan        1444.06
# ..     ...             ...            ...
# 187     12          Malibu        3500.51
# 188     12          Miller         356.93
# 189     12        Smirnoff        1602.54
# 190     12     Sutter Home         308.49
# 191     12     Yellow Tail        2844.47
#
# [192 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       46534.73
# 1      Monday       45869.02
# 2    Saturday       47314.04
# 3      Sunday       46608.55
# 4    Thursday       42810.95
# 5     Tuesday       45829.40
# 6   Wednesday       51405.23
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1        9048.75
# 1      2        7661.80
# 2      3        5788.31
# 3      4        4510.07
# 4      5        7163.31
# 5      6        7957.46
# 6      7        3227.23
# 7      8        4860.24
# 8      9        6403.28
# 9     10        4824.31
# 10    11        4737.46
# 11    12        7591.88
# 12    13        4208.24
# 13    14        4701.64
# 14    15        5214.43
# 15    16        7309.80
# 16    17        4283.03
# 17    18        7144.09
# 18    19        7720.83
# 19    20        7262.84
# 20    21        8169.37
# 21    22        7304.46
# 22    23        6177.34
# 23    24        6382.75
# 24    25        4459.24
# 25    26        6560.96
# 26    27        6633.04
# 27    28        6582.68
# 28    29        8471.90
# 29    30        5345.90
# 30    31        6727.15
# 31    32        7952.84
# 32    33        4439.90
# 33    34        6979.19
# 34    35        6792.20
# 35    36        5460.74
# 36    37        6552.34
# 37    38        5372.12
# 38    39        6364.83
# 39    40        6219.34
# 40    41        6769.43
# 41    42        8189.34
# 42    43        5460.92
# 43    44        5300.38
# 44    45        8084.91
# 45    46        7387.64
# 46    47        5317.09
# 47    48        5571.05
# 48    49        4625.00
# 49    50        8010.81
# 50    51        7167.29
# 51    52        3920.77
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      232449.33
# 1  Weekend       93922.59
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       21518.86
# 1       1  Weekend        7738.76
# 2       2  Weekday       17614.77
# 3       2  Weekend        4839.31
# 4       3  Weekday       18152.91
# 5       3  Weekend        7274.91
# 6       4  Weekday       13586.86
# 7       4  Weekend        8764.86
# 8       5  Weekday       23927.62
# 9       5  Weekend        9331.91
# 10      6  Weekday       20934.99
# 11      6  Weekend        5210.01
# 12      7  Weekday       20261.03
# 13      7  Weekend        9873.76
# 14      8  Weekday       20697.89
# 15      8  Weekend        8217.53
# 16      9  Weekday       17621.81
# 17      9  Weekend        7440.66
# 18     10  Weekday       19004.51
# 19     10  Weekend       10059.64
# 20     11  Weekday       20751.79
# 21     11  Weekend        7710.94
# 22     12  Weekday       18376.29
# 23     12  Weekend        7460.30
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       38324.13       29257.62
# 1       2       20153.77       22454.08
# 2       3       32679.13       25427.82
# 3       4       22173.33       22351.72
# 4       5       33052.06       33259.53
# 5       6       24635.26       26145.00
# 6       7       32080.84       30134.79
# 7       8       20919.72       28915.42
# 8       9       34837.55       25062.47
# 9      10       24696.68       29064.15
# 10     11       28754.93       28462.73
# 11     12       21011.69       25836.59
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01           0.00           0.00
# 1    2023-01-02           0.00        1248.00
# 2    2023-01-03           0.00        1399.14
# 3    2023-01-04        5120.82        1028.04
# 4    2023-01-05        2729.56        1732.27
# ..          ...            ...            ...
# 361  2023-12-28           0.00         619.31
# 362  2023-12-29           0.00        1040.93
# 363  2023-12-30           0.00         165.09
# 364  2023-12-31        1280.12         629.40
# 365  2024-01-01        2302.20         935.92
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 27197.66
#
# Key: Stockout Threshold
# Value:
# 13598.83
#
# Key: Overstock Threshold
# Value:
# 32637.192
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4f792f350>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       3158.77  5048.98  5201.47  3287.27
#              Coors           4769.25  2259.88  3007.70  3992.18
#              Heineken        4071.95  7095.20  3556.19  4814.09
#              Miller          5645.78  2172.13  6174.64  2488.36
# Rum          Bacardi         6015.72  3689.42  7540.61  6175.14
#              Captain Morgan  4127.72  6468.24  2648.97  4642.57
#              Malibu          2836.96  3150.37  6041.56  7028.14
# Vodka        Absolut         5700.94  3847.14  2972.66  5837.49
#              Grey Goose      8785.80  8327.77  6151.74  4607.99
#              Smirnoff        4294.50  3790.30  6097.20  2920.29
# Whiskey      Jack Daniels     819.60  7355.69  3842.71  6850.36
#              Jameson         6427.67  4224.49  6787.45  6373.52
#              Jim Beam        7978.36  6222.86  5834.82  3741.54
# Wine         Barefoot        3563.54  5401.54  4395.25  5885.89
#              Sutter Home     6333.40  4147.40  7857.22  2296.90
#              Yellow Tail     8059.39  7837.66  7085.02  6606.56
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5561.986667         2780.993333             6674.384
# 1          Rum    5030.451667         2515.225833             6036.542
# 2        Vodka    5277.818333         2638.909167             6333.382
# 3      Whiskey    5538.255833         2769.127917             6645.907
# 4         Wine    5789.147500         2894.573750             6946.977
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5561.986667         2780.993333             6674.384
# 1          Rum    5030.451667         2515.225833             6036.542
# 2        Vodka    5277.818333         2638.909167             6333.382
# 3      Whiskey    5538.255833         2769.127917             6645.907
# 4         Wine    5789.147500         2894.573750             6946.977
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01          Rum  Captain Morgan           0.00
# 1     2023-01-01        Vodka      Grey Goose           0.00
# 2     2023-01-01      Whiskey        Jim Beam           0.00
# 3     2023-01-02          Rum         Bacardi         134.75
# 4     2023-01-02        Vodka         Absolut         376.31
# ...          ...          ...             ...            ...
# 1095  2023-12-31         Wine        Barefoot         287.53
# 1096  2024-01-01         Beer        Heineken         111.63
# 1097  2024-01-01          Rum          Malibu         416.29
# 1098  2024-01-01        Vodka        Smirnoff         252.39
# 1099  2024-01-01         Wine        Barefoot         155.61
#
# [1100 rows x 4 columns]

# %%
# Analyze Johnsonbar
# Run the analysis
Johnsonbar_analysis= analyze_bar_main(df, "Johnson's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in Johnsonbar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in Johnsonbar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 344184.38
#
# Key: Total Purchased (ml)
# Value:
# 364020.62
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Vodka      77030.94
# Beer       74739.28
# Rum        73387.74
# Wine       65733.94
# Whiskey    53292.48
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Captain Morgan    28319.66
# Malibu            26356.51
# Absolut           26070.31
# Smirnoff          25506.02
# Grey Goose        25454.61
# Barefoot          22087.13
# Sutter Home       22046.56
# Yellow Tail       21600.25
# Coors             19542.98
# Heineken          19525.87
# Budweiser         19345.17
# Jack Daniels      19002.59
# Bacardi           18711.57
# Jameson           17708.62
# Jim Beam          16581.27
# Miller            16325.26
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Captain Morgan    28319.66
# Malibu            26356.51
# Absolut           26070.31
# Smirnoff          25506.02
# Grey Goose        25454.61
# Barefoot          22087.13
# Sutter Home       22046.56
# Yellow Tail       21600.25
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Coors           19542.98
# Heineken        19525.87
# Budweiser       19345.17
# Jack Daniels    19002.59
# Bacardi         18711.57
# Jameson         17708.62
# Jim Beam        16581.27
# Miller          16325.26
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       33229.79
# 1       2       30167.60
# 2       3       29315.51
# 3       4       26159.02
# 4       5       26082.56
# 5       6       26991.85
# 6       7       27096.55
# 7       8       28941.10
# 8       9       28789.08
# 9      10       27175.87
# 10     11       33624.16
# 11     12       26611.29
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut        2160.81
# 1        1         Bacardi        2435.40
# 2        1        Barefoot        2360.22
# 3        1       Budweiser         357.34
# 4        1  Captain Morgan        2049.49
# ..     ...             ...            ...
# 187     12          Malibu        2466.74
# 188     12          Miller         940.39
# 189     12        Smirnoff         969.41
# 190     12     Sutter Home        1710.03
# 191     12     Yellow Tail        2150.55
#
# [192 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       52357.33
# 1      Monday       44597.63
# 2    Saturday       44623.94
# 3      Sunday       50271.14
# 4    Thursday       53835.10
# 5     Tuesday       50107.88
# 6   Wednesday       48391.36
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1       10089.13
# 1      2        7368.18
# 2      3        6718.77
# 3      4        7339.17
# 4      5        5507.33
# 5      6        9267.23
# 6      7        6863.10
# 7      8        8798.53
# 8      9        6267.34
# 9     10        4223.56
# 10    11        8088.52
# 11    12        8035.37
# 12    13        7162.42
# 13    14        7448.27
# 14    15        4342.77
# 15    16        6900.59
# 16    17        4451.64
# 17    18        4805.92
# 18    19        6160.21
# 19    20        6775.67
# 20    21        6096.92
# 21    22        6364.10
# 22    23        6339.00
# 23    24        7652.70
# 24    25        5924.34
# 25    26        5409.71
# 26    27        4127.19
# 27    28        6867.11
# 28    29        5812.65
# 29    30        7505.43
# 30    31        6043.59
# 31    32        8728.80
# 32    33        5352.93
# 33    34        6440.34
# 34    35        6114.56
# 35    36        6682.56
# 36    37        6199.43
# 37    38        7032.99
# 38    39        5926.22
# 39    40        5321.15
# 40    41        7398.58
# 41    42        6081.27
# 42    43        6082.43
# 43    44        6882.90
# 44    45        8848.53
# 45    46        8081.78
# 46    47        7455.40
# 47    48        5767.46
# 48    49        5960.43
# 49    50        7183.16
# 50    51        6412.30
# 51    52        5474.70
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      249289.30
# 1  Weekend       94895.08
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       24451.76
# 1       1  Weekend        8778.03
# 2       2  Weekday       22110.45
# 3       2  Weekend        8057.15
# 4       3  Weekday       22837.74
# 5       3  Weekend        6477.77
# 6       4  Weekday       18297.50
# 7       4  Weekend        7861.52
# 8       5  Weekday       20310.18
# 9       5  Weekend        5772.38
# 10      6  Weekday       17402.33
# 11      6  Weekend        9589.52
# 12      7  Weekday       18100.88
# 13      7  Weekend        8995.67
# 14      8  Weekday       21484.05
# 15      8  Weekend        7457.05
# 16      9  Weekday       19039.75
# 17      9  Weekend        9749.33
# 18     10  Weekday       20810.55
# 19     10  Weekend        6365.32
# 20     11  Weekday       24899.58
# 21     11  Weekend        8724.58
# 22     12  Weekday       19544.53
# 23     12  Weekend        7066.76
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       34642.47       33229.79
# 1       2       33576.19       30167.60
# 2       3       37969.65       29315.51
# 3       4       34193.29       26159.02
# 4       5       24412.79       26082.56
# 5       6       29134.92       26991.85
# 6       7       38457.84       27096.55
# 7       8       28156.01       28941.10
# 8       9       24132.74       28789.08
# 9      10       31042.67       27175.87
# 10     11       29555.63       33624.16
# 11     12       18746.42       26611.29
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01           0.00           0.00
# 1    2023-01-02         960.03        1287.62
# 2    2023-01-03        1398.53        1018.07
# 3    2023-01-04           0.00        1385.56
# 4    2023-01-05        1961.69        1386.06
# ..          ...            ...            ...
# 361  2023-12-28           0.00        1163.00
# 362  2023-12-29        1200.68        1551.89
# 363  2023-12-30           0.00         668.03
# 364  2023-12-31           0.00         335.15
# 365  2024-01-01           0.00         954.95
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 28682.031666666662
#
# Key: Stockout Threshold
# Value:
# 14341.015833333331
#
# Key: Overstock Threshold
# Value:
# 34418.437999999995
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4fa5ef350>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       5448.88  5182.87  5192.02  3521.40
#              Coors           4101.10  3536.07  6225.69  5680.12
#              Heineken        5495.19  3796.88  3689.04  6544.76
#              Miller          5069.73  3441.29  3946.48  3867.76
# Rum          Bacardi         4994.18  3223.68  4015.67  6478.04
#              Captain Morgan  7955.06  8385.84  4415.91  7562.85
#              Malibu          6698.91  4814.27  6454.40  8388.93
# Vodka        Absolut         7060.87  5904.95  7013.05  6091.44
#              Grey Goose      5626.92  6436.03  6248.57  7143.09
#              Smirnoff        6822.39  6538.82  7384.07  4760.74
# Whiskey      Jack Daniels    3629.76  4854.46  4716.40  5801.97
#              Jameson         4287.17  4207.94  4718.51  4495.00
#              Jim Beam        7310.39  3793.24  1145.69  4331.95
# Wine         Barefoot        2761.72  6842.45  7547.78  4935.18
#              Sutter Home     5285.72  4293.71  7018.27  5448.86
#              Yellow Tail     7041.12  6304.59  3297.95  4956.59
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    6228.273333         3114.136667             7473.928
# 1          Rum    6115.645000         3057.822500             7338.774
# 2        Vodka    6419.245000         3209.622500             7703.094
# 3      Whiskey    4441.040000         2220.520000             5329.248
# 4         Wine    5477.828333         2738.914167             6573.394
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    6228.273333         3114.136667             7473.928
# 1          Rum    6115.645000         3057.822500             7338.774
# 2        Vodka    6419.245000         3209.622500             7703.094
# 3      Whiskey    4441.040000         2220.520000             5329.248
# 4         Wine    5477.828333         2738.914167             6573.394
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01         Beer           Coors           0.00
# 1     2023-01-01        Vodka      Grey Goose           0.00
# 2     2023-01-01         Wine     Yellow Tail           0.00
# 3     2023-01-02         Beer           Coors         225.46
# 4     2023-01-02        Vodka        Smirnoff         543.16
# ...          ...          ...             ...            ...
# 1101  2023-12-31          Rum  Captain Morgan         138.50
# 1102  2023-12-31         Wine     Sutter Home         196.65
# 1103  2024-01-01         Beer           Coors         133.06
# 1104  2024-01-01          Rum          Malibu         278.16
# 1105  2024-01-01        Vodka      Grey Goose         543.73
#
# [1106 rows x 4 columns]

# %%
# Analyze Smithsbar
# Run the analysis
SmithsBar_analysis= analyze_bar_main(df, "Smith's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in Johnsonbar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in Johnsonbar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 344184.38
#
# Key: Total Purchased (ml)
# Value:
# 364020.62
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Vodka      77030.94
# Beer       74739.28
# Rum        73387.74
# Wine       65733.94
# Whiskey    53292.48
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Captain Morgan    28319.66
# Malibu            26356.51
# Absolut           26070.31
# Smirnoff          25506.02
# Grey Goose        25454.61
# Barefoot          22087.13
# Sutter Home       22046.56
# Yellow Tail       21600.25
# Coors             19542.98
# Heineken          19525.87
# Budweiser         19345.17
# Jack Daniels      19002.59
# Bacardi           18711.57
# Jameson           17708.62
# Jim Beam          16581.27
# Miller            16325.26
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Captain Morgan    28319.66
# Malibu            26356.51
# Absolut           26070.31
# Smirnoff          25506.02
# Grey Goose        25454.61
# Barefoot          22087.13
# Sutter Home       22046.56
# Yellow Tail       21600.25
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Coors           19542.98
# Heineken        19525.87
# Budweiser       19345.17
# Jack Daniels    19002.59
# Bacardi         18711.57
# Jameson         17708.62
# Jim Beam        16581.27
# Miller          16325.26
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       33229.79
# 1       2       30167.60
# 2       3       29315.51
# 3       4       26159.02
# 4       5       26082.56
# 5       6       26991.85
# 6       7       27096.55
# 7       8       28941.10
# 8       9       28789.08
# 9      10       27175.87
# 10     11       33624.16
# 11     12       26611.29
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut        2160.81
# 1        1         Bacardi        2435.40
# 2        1        Barefoot        2360.22
# 3        1       Budweiser         357.34
# 4        1  Captain Morgan        2049.49
# ..     ...             ...            ...
# 187     12          Malibu        2466.74
# 188     12          Miller         940.39
# 189     12        Smirnoff         969.41
# 190     12     Sutter Home        1710.03
# 191     12     Yellow Tail        2150.55
#
# [192 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       52357.33
# 1      Monday       44597.63
# 2    Saturday       44623.94
# 3      Sunday       50271.14
# 4    Thursday       53835.10
# 5     Tuesday       50107.88
# 6   Wednesday       48391.36
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1       10089.13
# 1      2        7368.18
# 2      3        6718.77
# 3      4        7339.17
# 4      5        5507.33
# 5      6        9267.23
# 6      7        6863.10
# 7      8        8798.53
# 8      9        6267.34
# 9     10        4223.56
# 10    11        8088.52
# 11    12        8035.37
# 12    13        7162.42
# 13    14        7448.27
# 14    15        4342.77
# 15    16        6900.59
# 16    17        4451.64
# 17    18        4805.92
# 18    19        6160.21
# 19    20        6775.67
# 20    21        6096.92
# 21    22        6364.10
# 22    23        6339.00
# 23    24        7652.70
# 24    25        5924.34
# 25    26        5409.71
# 26    27        4127.19
# 27    28        6867.11
# 28    29        5812.65
# 29    30        7505.43
# 30    31        6043.59
# 31    32        8728.80
# 32    33        5352.93
# 33    34        6440.34
# 34    35        6114.56
# 35    36        6682.56
# 36    37        6199.43
# 37    38        7032.99
# 38    39        5926.22
# 39    40        5321.15
# 40    41        7398.58
# 41    42        6081.27
# 42    43        6082.43
# 43    44        6882.90
# 44    45        8848.53
# 45    46        8081.78
# 46    47        7455.40
# 47    48        5767.46
# 48    49        5960.43
# 49    50        7183.16
# 50    51        6412.30
# 51    52        5474.70
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      249289.30
# 1  Weekend       94895.08
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       24451.76
# 1       1  Weekend        8778.03
# 2       2  Weekday       22110.45
# 3       2  Weekend        8057.15
# 4       3  Weekday       22837.74
# 5       3  Weekend        6477.77
# 6       4  Weekday       18297.50
# 7       4  Weekend        7861.52
# 8       5  Weekday       20310.18
# 9       5  Weekend        5772.38
# 10      6  Weekday       17402.33
# 11      6  Weekend        9589.52
# 12      7  Weekday       18100.88
# 13      7  Weekend        8995.67
# 14      8  Weekday       21484.05
# 15      8  Weekend        7457.05
# 16      9  Weekday       19039.75
# 17      9  Weekend        9749.33
# 18     10  Weekday       20810.55
# 19     10  Weekend        6365.32
# 20     11  Weekday       24899.58
# 21     11  Weekend        8724.58
# 22     12  Weekday       19544.53
# 23     12  Weekend        7066.76
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       34642.47       33229.79
# 1       2       33576.19       30167.60
# 2       3       37969.65       29315.51
# 3       4       34193.29       26159.02
# 4       5       24412.79       26082.56
# 5       6       29134.92       26991.85
# 6       7       38457.84       27096.55
# 7       8       28156.01       28941.10
# 8       9       24132.74       28789.08
# 9      10       31042.67       27175.87
# 10     11       29555.63       33624.16
# 11     12       18746.42       26611.29
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01           0.00           0.00
# 1    2023-01-02         960.03        1287.62
# 2    2023-01-03        1398.53        1018.07
# 3    2023-01-04           0.00        1385.56
# 4    2023-01-05        1961.69        1386.06
# ..          ...            ...            ...
# 361  2023-12-28           0.00        1163.00
# 362  2023-12-29        1200.68        1551.89
# 363  2023-12-30           0.00         668.03
# 364  2023-12-31           0.00         335.15
# 365  2024-01-01           0.00         954.95
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 28682.031666666662
#
# Key: Stockout Threshold
# Value:
# 14341.015833333331
#
# Key: Overstock Threshold
# Value:
# 34418.437999999995
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4fa5ef350>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       5448.88  5182.87  5192.02  3521.40
#              Coors           4101.10  3536.07  6225.69  5680.12
#              Heineken        5495.19  3796.88  3689.04  6544.76
#              Miller          5069.73  3441.29  3946.48  3867.76
# Rum          Bacardi         4994.18  3223.68  4015.67  6478.04
#              Captain Morgan  7955.06  8385.84  4415.91  7562.85
#              Malibu          6698.91  4814.27  6454.40  8388.93
# Vodka        Absolut         7060.87  5904.95  7013.05  6091.44
#              Grey Goose      5626.92  6436.03  6248.57  7143.09
#              Smirnoff        6822.39  6538.82  7384.07  4760.74
# Whiskey      Jack Daniels    3629.76  4854.46  4716.40  5801.97
#              Jameson         4287.17  4207.94  4718.51  4495.00
#              Jim Beam        7310.39  3793.24  1145.69  4331.95
# Wine         Barefoot        2761.72  6842.45  7547.78  4935.18
#              Sutter Home     5285.72  4293.71  7018.27  5448.86
#              Yellow Tail     7041.12  6304.59  3297.95  4956.59
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    6228.273333         3114.136667             7473.928
# 1          Rum    6115.645000         3057.822500             7338.774
# 2        Vodka    6419.245000         3209.622500             7703.094
# 3      Whiskey    4441.040000         2220.520000             5329.248
# 4         Wine    5477.828333         2738.914167             6573.394
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    6228.273333         3114.136667             7473.928
# 1          Rum    6115.645000         3057.822500             7338.774
# 2        Vodka    6419.245000         3209.622500             7703.094
# 3      Whiskey    4441.040000         2220.520000             5329.248
# 4         Wine    5477.828333         2738.914167             6573.394
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01         Beer           Coors           0.00
# 1     2023-01-01        Vodka      Grey Goose           0.00
# 2     2023-01-01         Wine     Yellow Tail           0.00
# 3     2023-01-02         Beer           Coors         225.46
# 4     2023-01-02        Vodka        Smirnoff         543.16
# ...          ...          ...             ...            ...
# 1101  2023-12-31          Rum  Captain Morgan         138.50
# 1102  2023-12-31         Wine     Sutter Home         196.65
# 1103  2024-01-01         Beer           Coors         133.06
# 1104  2024-01-01          Rum          Malibu         278.16
# 1105  2024-01-01        Vodka      Grey Goose         543.73
#
# [1106 rows x 4 columns]

# %%
# Analyze TaylorsBar
# Run the analysis
TaylorsBar_analysis= analyze_bar_main(df, "Taylor's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in TaylorsBar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in TaylorsBar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 315176.56
#
# Key: Total Purchased (ml)
# Value:
# 343762.47
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Vodka      69766.61
# Whiskey    68906.96
# Rum        61383.12
# Beer       61026.88
# Wine       54092.99
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Grey Goose        28017.89
# Jim Beam          24368.84
# Smirnoff          23242.64
# Jack Daniels      23096.93
# Captain Morgan    22766.61
# Malibu            22042.69
# Budweiser         22022.14
# Barefoot          21726.79
# Jameson           21441.19
# Absolut           18506.08
# Bacardi           16573.82
# Yellow Tail       16415.18
# Sutter Home       15951.02
# Coors             14578.49
# Miller            14317.58
# Heineken          10108.67
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Grey Goose        28017.89
# Jim Beam          24368.84
# Smirnoff          23242.64
# Jack Daniels      23096.93
# Captain Morgan    22766.61
# Malibu            22042.69
# Budweiser         22022.14
# Barefoot          21726.79
# Jameson           21441.19
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Absolut        18506.08
# Bacardi        16573.82
# Yellow Tail    16415.18
# Sutter Home    15951.02
# Coors          14578.49
# Miller         14317.58
# Heineken       10108.67
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       32819.74
# 1       2       26978.62
# 2       3       24797.17
# 3       4       26624.74
# 4       5       29293.87
# 5       6       23473.18
# 6       7       27598.00
# 7       8       23656.79
# 8       9       23848.72
# 9      10       22879.60
# 10     11       24044.24
# 11     12       29161.89
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut        3178.53
# 1        1         Bacardi        1867.72
# 2        1        Barefoot        2009.11
# 3        1       Budweiser        3460.57
# 4        1  Captain Morgan        2768.92
# ..     ...             ...            ...
# 187     12          Malibu        2741.01
# 188     12          Miller           0.00
# 189     12        Smirnoff        3386.32
# 190     12     Sutter Home        2296.35
# 191     12     Yellow Tail        2093.59
#
# [192 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       44062.37
# 1      Monday       43584.80
# 2    Saturday       46178.39
# 3      Sunday       44145.45
# 4    Thursday       46617.70
# 5     Tuesday       46145.19
# 6   Wednesday       44442.66
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1       10743.62
# 1      2        7412.27
# 2      3        7761.54
# 3      4        5504.52
# 4      5        6417.22
# 5      6        5055.70
# 6      7        6488.43
# 7      8        8468.58
# 8      9        5445.97
# 9     10        5645.83
# 10    11        6082.23
# 11    12        6357.27
# 12    13        4773.71
# 13    14        6327.45
# 14    15        5868.98
# 15    16        6157.52
# 16    17        6709.43
# 17    18        6655.93
# 18    19        6008.74
# 19    20        8193.62
# 20    21        6435.61
# 21    22        4148.73
# 22    23        6242.13
# 23    24        5403.07
# 24    25        5431.40
# 25    26        5631.31
# 26    27        5486.03
# 27    28        6381.67
# 28    29        6052.70
# 29    30        6374.47
# 30    31        6259.81
# 31    32        5492.37
# 32    33        4162.65
# 33    34        6129.20
# 34    35        6805.85
# 35    36        5243.65
# 36    37        5690.67
# 37    38        5685.17
# 38    39        4330.18
# 39    40        3538.99
# 40    41        5857.76
# 41    42        6320.18
# 42    43        5827.69
# 43    44        5764.09
# 44    45        7009.09
# 45    46        5208.21
# 46    47        3878.79
# 47    48        5979.45
# 48    49        7032.89
# 49    50       10045.09
# 50    51        4250.10
# 51    52        4999.00
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      224852.72
# 1  Weekend       90323.84
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       24544.12
# 1       1  Weekend        8275.62
# 2       2  Weekday       19594.68
# 3       2  Weekend        7383.94
# 4       3  Weekday       18317.59
# 5       3  Weekend        6479.58
# 6       4  Weekday       18265.10
# 7       4  Weekend        8359.64
# 8       5  Weekday       20810.00
# 9       5  Weekend        8483.87
# 10      6  Weekday       16776.58
# 11      6  Weekend        6696.60
# 12      7  Weekday       19112.10
# 13      7  Weekend        8485.90
# 14      8  Weekday       18695.94
# 15      8  Weekend        4960.85
# 16      9  Weekday       14523.44
# 17      9  Weekend        9325.28
# 18     10  Weekday       15770.27
# 19     10  Weekend        7109.33
# 20     11  Weekday       18015.08
# 21     11  Weekend        6029.16
# 22     12  Weekday       20427.82
# 23     12  Weekend        8734.07
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       32022.69       32819.74
# 1       2       29841.46       26978.62
# 2       3       29984.09       24797.17
# 3       4       18218.40       26624.74
# 4       5       24646.75       29293.87
# 5       6       33383.99       23473.18
# 6       7       28436.86       27598.00
# 7       8       31359.00       23656.79
# 8       9       24095.86       23848.72
# 9      10       28746.48       22879.60
# 10     11       31934.73       24044.24
# 11     12       31092.16       29161.89
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01           0.00           0.00
# 1    2023-01-02        1978.16        1397.97
# 2    2023-01-03        1712.07        1405.96
# 3    2023-01-04        1069.94         913.71
# 4    2023-01-05           0.00        1247.06
# ..          ...            ...            ...
# 361  2023-12-28           0.00         537.42
# 362  2023-12-29           0.00         934.16
# 363  2023-12-30        1201.44         893.92
# 364  2023-12-31        1182.03         893.79
# 365  2024-01-01        5165.41        1252.81
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 26264.713333333333
#
# Key: Stockout Threshold
# Value:
# 13132.356666666667
#
# Key: Overstock Threshold
# Value:
# 31517.656
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4f790ac90>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       3492.09  6708.28  4959.96  6861.81
#              Coors           3021.52  4050.03  3012.20  4494.74
#              Heineken        1974.03  1827.52  5111.48  1195.64
#              Miller          4388.37  2848.59  3538.63  3541.99
# Rum          Bacardi         4338.04  3812.88  4062.45  4360.45
#              Captain Morgan  4699.98  5866.28  4712.84  7487.51
#              Malibu          5180.67  4788.31  5504.11  6569.60
# Vodka        Absolut         4479.66  2693.86  4025.14  7307.42
#              Grey Goose      9124.20  7055.49  7098.71  4739.49
#              Smirnoff        4120.63  5753.04  6407.08  6961.89
# Whiskey      Jack Daniels    5497.33  5881.09  5210.37  6508.14
#              Jameson         4991.35  6883.87  3439.22  6126.75
#              Jim Beam        4047.07  6825.83  5957.20  7538.74
# Wine         Barefoot        6751.07  4526.69  4747.77  5701.26
#              Sutter Home     3615.09  4959.41  2868.92  4507.60
#              Yellow Tail     1051.46  6234.61  4071.89  5057.22
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5085.573333         2542.786667             6102.688
# 1          Rum    5115.260000         2557.630000             6138.312
# 2        Vodka    5813.884167         2906.942083             6976.661
# 3      Whiskey    5742.246667         2871.123333             6890.696
# 4         Wine    4507.749167         2253.874583             5409.299
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5085.573333         2542.786667             6102.688
# 1          Rum    5115.260000         2557.630000             6138.312
# 2        Vodka    5813.884167         2906.942083             6976.661
# 3      Whiskey    5742.246667         2871.123333             6890.696
# 4         Wine    4507.749167         2253.874583             5409.299
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01        Vodka         Absolut           0.00
# 1     2023-01-01      Whiskey    Jack Daniels           0.00
# 2     2023-01-01         Wine     Sutter Home           0.00
# 3     2023-01-02         Beer           Coors         310.20
# 4     2023-01-02          Rum          Malibu         497.71
# ...          ...          ...             ...            ...
# 1083  2023-12-31      Whiskey        Jim Beam         349.75
# 1084  2023-12-31         Wine     Sutter Home           0.00
# 1085  2024-01-01         Beer       Budweiser         558.72
# 1086  2024-01-01          Rum  Captain Morgan         440.76
# 1087  2024-01-01      Whiskey        Jim Beam         253.33
#
# [1088 rows x 4 columns]

# %%
# Analyze TaylorsBar
# Run the analysis
ThomasBar_analysis= analyze_bar_main(df, "Thomas's Bar")

# 1️⃣ Print only keys
print("===== KEYS =====")
for key in ThomasBar_analysis.keys():
    print(key)

# 2️⃣ Print keys + values
print("\n===== KEYS + VALUES =====")
for key, value in ThomasBar_analysis.items():
    print(f"\nKey: {key}")
    print("Value:")
    print(value)
# Out:
# ===== KEYS =====
# Total Consumed (ml)
# Total Purchased (ml)
# Alcohol Type Consumption
# Brand Consumption
# Fast Movers
# Slow Movers
# Monthly Consumption
# Monthly Brand Consumption
# Day Of Week Consumption
# Weekly Consumption Yearly
# Weekend Consumption
# Monthly Weekend
# Monthly Balance
# Daily Summary
# Avg Monthly Consumption
# Stockout Threshold
# Overstock Threshold
# Seasonality Decomposition
# Standby Season-Wise
# Alcohol Type Monthly Average
# Alcohol Type Thresholds
# Daily Brand Alcohol Consumption
#
# ===== KEYS + VALUES =====
#
# Key: Total Consumed (ml)
# Value:
# 318415.94
#
# Key: Total Purchased (ml)
# Value:
# 340526.43
#
# Key: Alcohol Type Consumption
# Value:
# Alcohol Type
# Vodka      70357.19
# Rum        65716.76
# Whiskey    65540.32
# Beer       63412.01
# Wine       53389.66
# Name: Consumed (ml), dtype: float64
#
# Key: Brand Consumption
# Value:
# Brand Name
# Grey Goose        28510.30
# Jim Beam          25158.15
# Jack Daniels      24544.53
# Bacardi           24164.80
# Miller            21842.30
# Malibu            21676.34
# Smirnoff          21417.85
# Barefoot          21030.86
# Absolut           20429.04
# Captain Morgan    19875.62
# Yellow Tail       18394.35
# Jameson           15837.64
# Budweiser         15071.10
# Sutter Home       13964.45
# Heineken          13302.41
# Coors             13196.20
# Name: Consumed (ml), dtype: float64
#
# Key: Fast Movers
# Value:
# Brand Name
# Grey Goose      28510.30
# Jim Beam        25158.15
# Jack Daniels    24544.53
# Bacardi         24164.80
# Miller          21842.30
# Malibu          21676.34
# Smirnoff        21417.85
# Barefoot        21030.86
# Absolut         20429.04
# Name: Consumed (ml), dtype: float64
#
# Key: Slow Movers
# Value:
# Brand Name
# Captain Morgan    19875.62
# Yellow Tail       18394.35
# Jameson           15837.64
# Budweiser         15071.10
# Sutter Home       13964.45
# Heineken          13302.41
# Coors             13196.20
# Name: Consumed (ml), dtype: float64
#
# Key: Monthly Consumption
# Value:
#     Month  Consumed (ml)
# 0       1       32646.30
# 1       2       25392.94
# 2       3       24604.86
# 3       4       24513.06
# 4       5       25709.46
# 5       6       27848.84
# 6       7       25102.92
# 7       8       22633.99
# 8       9       26218.95
# 9      10       31030.03
# 10     11       26446.51
# 11     12       26268.08
#
# Key: Monthly Brand Consumption
# Value:
#      Month      Brand Name  Consumed (ml)
# 0        1         Absolut         969.40
# 1        1         Bacardi        3036.48
# 2        1        Barefoot        2233.78
# 3        1       Budweiser        2008.35
# 4        1  Captain Morgan        2469.44
# ..     ...             ...            ...
# 187     12          Malibu        1028.21
# 188     12          Miller        1145.24
# 189     12        Smirnoff        2181.98
# 190     12     Sutter Home         438.56
# 191     12     Yellow Tail        2781.61
#
# [192 rows x 3 columns]
#
# Key: Day Of Week Consumption
# Value:
#   Day_of_Week  Consumed (ml)
# 0      Friday       46802.13
# 1      Monday       45705.96
# 2    Saturday       44645.23
# 3      Sunday       42151.61
# 4    Thursday       46341.86
# 5     Tuesday       47518.66
# 6   Wednesday       45250.49
#
# Key: Weekly Consumption Yearly
# Value:
#     Week  Consumed (ml)
# 0      1       10378.29
# 1      2        7551.46
# 2      3        6090.69
# 3      4        7011.20
# 4      5        5987.14
# 5      6        6571.38
# 6      7        4750.47
# 7      8        7345.92
# 8      9        7033.12
# 9     10        4042.71
# 10    11        4465.14
# 11    12        5420.65
# 12    13        7609.68
# 13    14        5244.59
# 14    15        3896.35
# 15    16        8176.00
# 16    17        5582.37
# 17    18        4404.71
# 18    19        6114.79
# 19    20        6999.54
# 20    21        6571.08
# 21    22        4847.53
# 22    23        5761.04
# 23    24        7943.81
# 24    25        6237.11
# 25    26        7352.15
# 26    27        5492.47
# 27    28        5158.05
# 28    29        5837.94
# 29    30        5364.25
# 30    31        5449.10
# 31    32        4767.13
# 32    33        4780.70
# 33    34        6012.62
# 34    35        3545.14
# 35    36        5799.82
# 36    37        7507.90
# 37    38        5338.47
# 38    39        7328.02
# 39    40        8141.98
# 40    41        8193.02
# 41    42        5676.22
# 42    43        6612.81
# 43    44        6536.93
# 44    45        4339.91
# 45    46        6283.23
# 46    47        5853.54
# 47    48        7119.09
# 48    49        6007.25
# 49    50        6535.33
# 50    51        4779.74
# 51    52        6566.36
#
# Key: Weekend Consumption
# Value:
#    Weekend  Consumed (ml)
# 0  Weekday      231619.10
# 1  Weekend       86796.84
#
# Key: Monthly Weekend
# Value:
#     Month  Weekend  Consumed (ml)
# 0       1  Weekday       25048.98
# 1       1  Weekend        7597.32
# 2       2  Weekday       19475.32
# 3       2  Weekend        5917.62
# 4       3  Weekday       19419.52
# 5       3  Weekend        5185.34
# 6       4  Weekday       15675.50
# 7       4  Weekend        8837.56
# 8       5  Weekday       18475.21
# 9       5  Weekend        7234.25
# 10      6  Weekday       21305.34
# 11      6  Weekend        6543.50
# 12      7  Weekday       17457.77
# 13      7  Weekend        7645.15
# 14      8  Weekday       16691.32
# 15      8  Weekend        5942.67
# 16      9  Weekday       18132.86
# 17      9  Weekend        8086.09
# 18     10  Weekday       21148.81
# 19     10  Weekend        9881.22
# 20     11  Weekday       20620.54
# 21     11  Weekend        5825.97
# 22     12  Weekday       18167.93
# 23     12  Weekend        8100.15
#
# Key: Monthly Balance
# Value:
#     Month  Purchase (ml)  Consumed (ml)
# 0       1       31541.22       32646.30
# 1       2       22838.76       25392.94
# 2       3       34186.50       24604.86
# 3       4       23809.87       24513.06
# 4       5       30667.02       25709.46
# 5       6       33481.97       27848.84
# 6       7       21595.40       25102.92
# 7       8       25046.56       22633.99
# 8       9       25453.96       26218.95
# 9      10       38258.88       31030.03
# 10     11       27051.56       26446.51
# 11     12       26594.73       26268.08
#
# Key: Daily Summary
# Value:
#            Date  Purchase (ml)  Consumed (ml)
# 0    2023-01-01        1400.76           0.00
# 1    2023-01-02        1931.70        1022.67
# 2    2023-01-03        2378.04        1340.70
# 3    2023-01-04        1339.48        1198.47
# 4    2023-01-05         527.19        1609.67
# ..          ...            ...            ...
# 361  2023-12-28        1207.72         996.30
# 362  2023-12-29        1763.19         920.08
# 363  2023-12-30        1043.55        1179.83
# 364  2023-12-31           0.00         833.78
# 365  2024-01-01        1195.45         701.12
#
# [366 rows x 3 columns]
#
# Key: Avg Monthly Consumption
# Value:
# 26534.661666666667
#
# Key: Stockout Threshold
# Value:
# 13267.330833333333
#
# Key: Overstock Threshold
# Value:
# 31841.593999999997
#
# Key: Seasonality Decomposition
# Value:
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x7ca4f6699a50>
#
# Key: Standby Season-Wise
# Value:
# Season                          Fall   Spring   Summer   Winter
# Alcohol Type Brand Name
# Beer         Budweiser       5072.02  2513.02  3281.45  4204.61
#              Coors           2548.71  2364.05  5707.86  2575.58
#              Heineken        2895.82  3452.42  3433.30  3520.87
#              Miller          4415.45  7562.78  5839.21  4024.86
# Rum          Bacardi         8096.07  3455.77  6867.96  5745.00
#              Captain Morgan  5089.45  4705.97  3154.54  6925.66
#              Malibu          6277.23  4475.83  7564.31  3358.97
# Vodka        Absolut         4782.29  7177.95  4549.18  3919.62
#              Grey Goose      6844.14  6386.11  5392.72  9887.33
#              Smirnoff        6805.44  3853.63  5691.48  5067.30
# Whiskey      Jack Daniels    6261.62  7277.28  4641.58  6364.05
#              Jameson         3048.01  4407.75  3953.93  4427.95
#              Jim Beam        6715.33  5498.06  7359.37  5585.39
# Wine         Barefoot        4972.27  6946.28  3028.32  6083.99
#              Sutter Home     3850.85  3008.36   569.26  6535.98
#              Yellow Tail     6020.79  1742.12  4551.28  6080.16
#
# Key: Alcohol Type Monthly Average
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5284.334167         2642.167083             6341.201
# 1          Rum    5476.396667         2738.198333             6571.676
# 2        Vodka    5863.099167         2931.549583             7035.719
# 3      Whiskey    5461.693333         2730.846667             6554.032
# 4         Wine    4449.138333         2224.569167             5338.966
#
# Key: Alcohol Type Thresholds
# Value:
#   Alcohol Type  Consumed (ml)  Stockout Threshold  Overstock Threshold
# 0         Beer    5284.334167         2642.167083             6341.201
# 1          Rum    5476.396667         2738.198333             6571.676
# 2        Vodka    5863.099167         2931.549583             7035.719
# 3      Whiskey    5461.693333         2730.846667             6554.032
# 4         Wine    4449.138333         2224.569167             5338.966
#
# Key: Daily Brand Alcohol Consumption
# Value:
#             Date Alcohol Type      Brand Name  Consumed (ml)
# 0     2023-01-01         Beer          Miller           0.00
# 1     2023-01-01          Rum          Malibu           0.00
# 2     2023-01-02          Rum  Captain Morgan         533.80
# 3     2023-01-02        Vodka        Smirnoff         345.11
# 4     2023-01-02      Whiskey         Jameson         143.76
# ...          ...          ...             ...            ...
# 1096  2023-12-30         Wine     Sutter Home         110.36
# 1097  2023-12-31        Vodka        Smirnoff         474.32
# 1098  2023-12-31      Whiskey         Jameson         359.46
# 1099  2024-01-01          Rum         Bacardi         572.60
# 1100  2024-01-01        Vodka         Absolut         128.52
#
# [1101 rows x 4 columns]

# %% [markdown]
# ## ARIMA Optimizer Development ##
# ## AutoRegressive Integrated Moving Average ##
#
# ---

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

class BarInventoryForecastOptimizer:
    def __init__(self, bars_data, arima_order=(1,1,1), safety_buffer=0.3):
        """
        bars_data: either
          • { bar_name: DataFrame }
          • { bar_name: { ..., 'Daily Brand Alcohol Consumption': DataFrame, ... } }
        """
        self.bars_data = bars_data
        self.arima_order = arima_order
        self.safety_buffer = safety_buffer

    def _get_df(self, bar_name):
        if bar_name not in self.bars_data:
            raise KeyError(f"Bar '{bar_name}' not in bars_data keys {list(self.bars_data)}")
        val = self.bars_data[bar_name]
        # if it's a dict, extract the nested DataFrame:
        if isinstance(val, dict):
            if 'Daily Brand Alcohol Consumption' not in val:
                raise KeyError(f"Missing 'Daily Brand Alcohol Consumption' in bars_data['{bar_name}']")
            df = val['Daily Brand Alcohol Consumption']
        else:
            df = val
        if not isinstance(df, pd.DataFrame):
            raise TypeError(f"bars_data['{bar_name}'] is not a DataFrame or nested dict with one.")
        return df.copy()

    def forecast_for_single_day(self, bar_name, target_date):
        # 1) grab the correct DF
        df = self._get_df(bar_name)

        # 2) normalize date column
        if 'Date Time Served' in df.columns:
            df['Date'] = pd.to_datetime(df['Date Time Served'])
        elif 'Date' in df.columns:
            df['Date'] = pd.to_datetime(df['Date'])
        else:
            raise KeyError("No 'Date' or 'Date Time Served' column found in DataFrame")

        last_date = df['Date'].max()
        td = pd.to_datetime(target_date)
        days = (td - last_date).days
        if days <= 0:
            raise ValueError(f"Target date {td.date()} must be after last data date {last_date.date()}")

        rows = []
        for (alc, brand), grp in df.groupby(['Alcohol Type','Brand Name']):
            ts = grp.set_index('Date')['Consumed (ml)'].asfreq('D').fillna(0)
            try:
                model = ARIMA(ts, order=self.arima_order).fit()
                fval = model.forecast(steps=days).iloc[-1]
                stock = round(fval * (1 + self.safety_buffer), 2)
            except Exception:
                fval = None
                stock = None
            rows.append({
                'Bar Name': bar_name,
                'Target Date': td.date(),
                'Alcohol Type': alc,
                'Brand Name': brand,
                'Forecasted Consumption (ml)': None if fval is None else round(fval, 2),
                'Stock to Maintain (ml)': stock
            })
        return pd.DataFrame(rows)

# %%
## seggrating the bars anlyzed data into the dataframe
bars_data = {
    "Anderson's Bar":   andersonsbar_analysis,
    "Brown's Bar":      BrownsBar_analysis,
    "Johnson's Bar":    Johnsonbar_analysis,
    "Smith's Bar":      SmithsBar_analysis,
    "Taylor's Bar":     TaylorsBar_analysis,
    "Thomas's Bar":     ThomasBar_analysis
}

# %%
## checking what vales it should accepte
print("Available bars:", list(bars_data.keys()))
# Out:
# Available bars: ["Anderson's Bar", "Brown's Bar", "Johnson's Bar", "Smith's Bar", "Taylor's Bar", "Thomas's Bar"]

# %% [markdown]
# ## Forecasting and Prediction ##

# %%
##Passing the vales in to the optimizers
optimizer = BarInventoryForecastOptimizer(bars_data)

# %%
# Predicting the future values to maintain the stock.
result = optimizer.forecast_for_single_day(
    bar_name="Anderson's Bar",
    target_date="2025-06-16"
)

for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Anderson's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 3.68 ml | Stock to Maintain: 4.79 ml
# Anderson's Bar | 2025-06-16 | Beer | Coors | Forecasted: 55.56 ml | Stock to Maintain: 72.23 ml
# Anderson's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 43.45 ml | Stock to Maintain: 56.48 ml
# Anderson's Bar | 2025-06-16 | Beer | Miller | Forecasted: 50.09 ml | Stock to Maintain: 65.11 ml
# Anderson's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 70.97 ml | Stock to Maintain: 92.26 ml
# Anderson's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 79.53 ml | Stock to Maintain: 103.39 ml
# Anderson's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 12.57 ml | Stock to Maintain: 16.34 ml
# Anderson's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 36.64 ml | Stock to Maintain: 47.64 ml
# Anderson's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 48.4 ml | Stock to Maintain: 62.92 ml
# Anderson's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 69.44 ml | Stock to Maintain: 90.27 ml
# Anderson's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 59.81 ml | Stock to Maintain: 77.75 ml
# Anderson's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 64.38 ml | Stock to Maintain: 83.7 ml
# Anderson's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 71.57 ml | Stock to Maintain: 93.05 ml
# Anderson's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 74.72 ml | Stock to Maintain: 97.14 ml
# Anderson's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 63.39 ml | Stock to Maintain: 82.41 ml
# Anderson's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 54.11 ml | Stock to Maintain: 70.34 ml

# %%
result = optimizer.forecast_for_single_day(
    bar_name="Brown's Bar",
    target_date="2025-06-16"
)

for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Brown's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 47.82 ml | Stock to Maintain: 62.17 ml
# Brown's Bar | 2025-06-16 | Beer | Coors | Forecasted: 39.85 ml | Stock to Maintain: 51.81 ml
# Brown's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 46.53 ml | Stock to Maintain: 60.49 ml
# Brown's Bar | 2025-06-16 | Beer | Miller | Forecasted: 47.56 ml | Stock to Maintain: 61.83 ml
# Brown's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 64.91 ml | Stock to Maintain: 84.39 ml
# Brown's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 50.3 ml | Stock to Maintain: 65.39 ml
# Brown's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 122.77 ml | Stock to Maintain: 159.6 ml
# Brown's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 46.32 ml | Stock to Maintain: 60.21 ml
# Brown's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 76.82 ml | Stock to Maintain: 99.86 ml
# Brown's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 54.88 ml | Stock to Maintain: 71.34 ml
# Brown's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 28.06 ml | Stock to Maintain: 36.47 ml
# Brown's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 68.71 ml | Stock to Maintain: 89.33 ml
# Brown's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 65.78 ml | Stock to Maintain: 85.51 ml
# Brown's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 53.95 ml | Stock to Maintain: 70.14 ml
# Brown's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 50.23 ml | Stock to Maintain: 65.3 ml
# Brown's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 81.71 ml | Stock to Maintain: 106.22 ml

# %%
result = optimizer.forecast_for_single_day(
    bar_name="Johnson's Bar",
    target_date="2025-06-16"
)
for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Johnson's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 54.92 ml | Stock to Maintain: 71.39 ml
# Johnson's Bar | 2025-06-16 | Beer | Coors | Forecasted: 53.39 ml | Stock to Maintain: 69.41 ml
# Johnson's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 54.5 ml | Stock to Maintain: 70.85 ml
# Johnson's Bar | 2025-06-16 | Beer | Miller | Forecasted: 46.08 ml | Stock to Maintain: 59.9 ml
# Johnson's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 56.97 ml | Stock to Maintain: 74.06 ml
# Johnson's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 78.78 ml | Stock to Maintain: 102.41 ml
# Johnson's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 72.51 ml | Stock to Maintain: 94.26 ml
# Johnson's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 76.22 ml | Stock to Maintain: 99.09 ml
# Johnson's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 69.79 ml | Stock to Maintain: 90.73 ml
# Johnson's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 71.56 ml | Stock to Maintain: 93.02 ml
# Johnson's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 52.65 ml | Stock to Maintain: 68.45 ml
# Johnson's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 49.09 ml | Stock to Maintain: 63.82 ml
# Johnson's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 64.64 ml | Stock to Maintain: 84.04 ml
# Johnson's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 62.55 ml | Stock to Maintain: 81.31 ml
# Johnson's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 60.92 ml | Stock to Maintain: 79.2 ml
# Johnson's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 60.77 ml | Stock to Maintain: 79.0 ml

# %%
result = optimizer.forecast_for_single_day(
    bar_name="Smith's Bar",
    target_date="2025-06-16"
)

for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Smith's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 38.61 ml | Stock to Maintain: 50.19 ml
# Smith's Bar | 2025-06-16 | Beer | Coors | Forecasted: 35.41 ml | Stock to Maintain: 46.03 ml
# Smith's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 48.17 ml | Stock to Maintain: 62.62 ml
# Smith's Bar | 2025-06-16 | Beer | Miller | Forecasted: 57.76 ml | Stock to Maintain: 75.09 ml
# Smith's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 54.0 ml | Stock to Maintain: 70.2 ml
# Smith's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 51.54 ml | Stock to Maintain: 67.0 ml
# Smith's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 68.33 ml | Stock to Maintain: 88.84 ml
# Smith's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 75.06 ml | Stock to Maintain: 97.57 ml
# Smith's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 68.9 ml | Stock to Maintain: 89.58 ml
# Smith's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 114.85 ml | Stock to Maintain: 149.31 ml
# Smith's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 51.29 ml | Stock to Maintain: 66.67 ml
# Smith's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 52.76 ml | Stock to Maintain: 68.59 ml
# Smith's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 62.49 ml | Stock to Maintain: 81.24 ml
# Smith's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 59.49 ml | Stock to Maintain: 77.33 ml
# Smith's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 80.48 ml | Stock to Maintain: 104.63 ml
# Smith's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 67.06 ml | Stock to Maintain: 87.18 ml

# %%
result = optimizer.forecast_for_single_day(
    bar_name="Taylor's Bar",
    target_date="2025-06-16"
)

for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Taylor's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 42.76 ml | Stock to Maintain: 55.59 ml
# Taylor's Bar | 2025-06-16 | Beer | Coors | Forecasted: 40.18 ml | Stock to Maintain: 52.24 ml
# Taylor's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 34.47 ml | Stock to Maintain: 44.82 ml
# Taylor's Bar | 2025-06-16 | Beer | Miller | Forecasted: 40.23 ml | Stock to Maintain: 52.29 ml
# Taylor's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 48.62 ml | Stock to Maintain: 63.21 ml
# Taylor's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 58.79 ml | Stock to Maintain: 76.43 ml
# Taylor's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 114.68 ml | Stock to Maintain: 149.08 ml
# Taylor's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 58.67 ml | Stock to Maintain: 76.28 ml
# Taylor's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 88.84 ml | Stock to Maintain: 115.49 ml
# Taylor's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 124.59 ml | Stock to Maintain: 161.96 ml
# Taylor's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 64.14 ml | Stock to Maintain: 83.38 ml
# Taylor's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 59.83 ml | Stock to Maintain: 77.77 ml
# Taylor's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 67.71 ml | Stock to Maintain: 88.02 ml
# Taylor's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 61.61 ml | Stock to Maintain: 80.09 ml
# Taylor's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 43.85 ml | Stock to Maintain: 57.01 ml
# Taylor's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 41.08 ml | Stock to Maintain: 53.4 ml

# %%
result = optimizer.forecast_for_single_day(
    bar_name="Thomas's Bar",
    target_date="2025-06-16"
)

for idx, row in result.iterrows():
    print(f"{row['Bar Name']} | {row['Target Date']} | {row['Alcohol Type']} | {row['Brand Name']} | Forecasted: {row['Forecasted Consumption (ml)']} ml | Stock to Maintain: {row['Stock to Maintain (ml)']} ml")
# Out:
# Thomas's Bar | 2025-06-16 | Beer | Budweiser | Forecasted: 60.71 ml | Stock to Maintain: 78.92 ml
# Thomas's Bar | 2025-06-16 | Beer | Coors | Forecasted: 37.04 ml | Stock to Maintain: 48.15 ml
# Thomas's Bar | 2025-06-16 | Beer | Heineken | Forecasted: 36.64 ml | Stock to Maintain: 47.63 ml
# Thomas's Bar | 2025-06-16 | Beer | Miller | Forecasted: 61.53 ml | Stock to Maintain: 79.99 ml
# Thomas's Bar | 2025-06-16 | Rum | Bacardi | Forecasted: 66.66 ml | Stock to Maintain: 86.66 ml
# Thomas's Bar | 2025-06-16 | Rum | Captain Morgan | Forecasted: 56.53 ml | Stock to Maintain: 73.49 ml
# Thomas's Bar | 2025-06-16 | Rum | Malibu | Forecasted: 59.6 ml | Stock to Maintain: 77.47 ml
# Thomas's Bar | 2025-06-16 | Vodka | Absolut | Forecasted: 56.83 ml | Stock to Maintain: 73.88 ml
# Thomas's Bar | 2025-06-16 | Vodka | Grey Goose | Forecasted: 117.25 ml | Stock to Maintain: 152.43 ml
# Thomas's Bar | 2025-06-16 | Vodka | Smirnoff | Forecasted: 65.53 ml | Stock to Maintain: 85.19 ml
# Thomas's Bar | 2025-06-16 | Whiskey | Jack Daniels | Forecasted: 69.18 ml | Stock to Maintain: 89.93 ml
# Thomas's Bar | 2025-06-16 | Whiskey | Jameson | Forecasted: 34.49 ml | Stock to Maintain: 44.84 ml
# Thomas's Bar | 2025-06-16 | Whiskey | Jim Beam | Forecasted: 69.8 ml | Stock to Maintain: 90.74 ml
# Thomas's Bar | 2025-06-16 | Wine | Barefoot | Forecasted: 58.8 ml | Stock to Maintain: 76.44 ml
# Thomas's Bar | 2025-06-16 | Wine | Sutter Home | Forecasted: 24.85 ml | Stock to Maintain: 32.3 ml
# Thomas's Bar | 2025-06-16 | Wine | Yellow Tail | Forecasted: 105.95 ml | Stock to Maintain: 137.73 ml
